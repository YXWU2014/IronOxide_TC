# %%
# Development mode: automatic reloading of modules
# %load_ext autoreload
# %autoreload 2

# %%
import pickle
from tc_python import *
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from multiprocessing import Pool
import os
from itertools import product
import time
import matplotlib
matplotlib.rcParams['font.family'] = 'FreeSans'

num_cpus = os.cpu_count()
print(f'cpu_count: {num_cpus}')
# Out:
# cpu_count: 40

# %%
basename = 'IronOxide_TC_calculations_TCFE'

current_directory = os.getcwd()
cache_fname = basename + '.ipynb' + "_cache"
output_fname = os.path.splitext(basename)[0]

print("Cache Filename: ", cache_fname)
print("Output Filename: ", output_fname)
print("Current Dir: ", current_directory)
# Out:
# Cache Filename:  IronOxide_TC_calculations_TCFE.ipynb_cache
# Output Filename:  IronOxide_TC_calculations_TCFE
# Current Dir:  /nethome/home3/yuxiang.wu/IronOxide_TC

# %% [markdown]
# ### TC functions
#
# #### `tc_calculation_FullEquil`: compute the equilibrium phase fraction as (acr, T)

# %%
def tc_calculation_FullEquil(tk):
    with TCPython() as start:
        batch_calculation = (
            start
            .set_cache_folder(os.path.join(current_directory, cache_fname))
            .set_ges_version(5)
            .select_database_and_elements("tcfe13", ["Fe", "O"])
            .deselect_phase("*")
            .select_phase("CORUNDUM SPINEL HALITE BCC_A2 LIQUID")
            # .select_database_and_elements("tcox10", ["Fe", "O"])
            # .deselect_phase("*")
            # .select_phase("CORUNDUM SPINEL HALITE")
            .select_database_and_elements("ssub5", ["Fe", "O"])
            .deselect_phase("*")
            .select_phase("GAS")
            .get_system()
            .with_batch_equilibrium_calculation()
            .set_condition("T", 100+273.15)
            .set_condition("P", 0.5)
            .set_condition("lnacr(o)", -400)
            .with_reference_state("O", 'GAS', tk, 10000)
            .disable_global_minimization()
        )

        # Generate condition combinations for equilibrium calculations
        k = 150
        list_of_conditions = [(("lnacr(o)", lnacr_o), ("T", tk))
                              for lnacr_o in np.linspace(-60, -5, k)]

        batch_calculation.set_conditions_for_equilibria(list_of_conditions)

        results = batch_calculation.calculate(
            ["np(CORUNDUM)", "np(SPINEL)", "np(HALITE)", "np(BCC_A2)", "np(LIQUID)"], 100)

        return (
            list_of_conditions,
            results.get_values_of('np(CORUNDUM)'),
            results.get_values_of('np(SPINEL)'),
            results.get_values_of('np(HALITE)'),
            results.get_values_of('np(BCC_A2)'),
            results.get_values_of('np(LIQUID)')
        )

# %% [markdown]
# #### `tc_calculation_Gmin`: compute the Gibbs energy as (database, phase, acr, T)

# %%
def tc_calculation_Gmin(tk, db, phase):
    with TCPython() as start:
        batch_calculation = (
            start
            .set_cache_folder(os.path.join(current_directory, cache_fname))
            .set_ges_version(5))

        batch_calculation = (
            batch_calculation
            .select_database_and_elements(db, ["Fe", "O"])
            .deselect_phase("*")
            .select_phase(f"{phase}")
            .select_database_and_elements("ssub5", ["Fe", "O"])
            .deselect_phase("*")
            .select_phase("GAS")
        )

        # Continue with the rest of the method chain
        batch_calculation = (
            batch_calculation
            .get_system()
            .with_batch_equilibrium_calculation()
            .set_condition("T", 100+273.15)
            .set_condition("P", 0.5)
            .set_condition("lnacr(o)", -400)
            .with_reference_state("O", 'GAS', tk, 10000)
            .disable_global_minimization()
        )

        # Generate condition combinations for equilibrium calculations
        k = 150
        list_of_conditions = [(("lnacr(o)", lnacr_o), ("T", tk))
                              for lnacr_o in np.linspace(-60, -5, k)]

        batch_calculation.set_conditions_for_equilibria(list_of_conditions)

        # run a calculation first
        results = batch_calculation.calculate([f"gm({phase})"], 100)

        # # turn "GAS" into Dormant and run the same calculation again
        # batch_calculation.set_phase_to_dormant("GAS")
        # results = batch_calculation.calculate([f"gm({phase})"], 100)

        return (
            list_of_conditions,
            results.get_values_of(f"gm({phase})")
        )

# %% [markdown]
# #### `tc_calculation_NormDrivingForce`: compute the Normalised Driving Force as (database, phase, acr, T)

# %%
def tc_calculation_NormDrivingForce(tk, db, phase):
    with TCPython() as start:
        batch_calculation = (
            start
            .set_cache_folder(os.path.join(current_directory, cache_fname))
            .set_ges_version(5))

        batch_calculation = (
            batch_calculation
            .select_database_and_elements(db, ["Fe", "O"])
            .deselect_phase("*")
            .select_phase(f"{phase}")
            .select_database_and_elements('ssub5', ["Fe", "O"])
            .deselect_phase("*")
            .select_phase("GAS")
        )

        # Continue with the rest of the method chain
        batch_calculation = (
            batch_calculation
            .get_system()
            .with_batch_equilibrium_calculation()
            .set_condition("T", 100+273.15)
            .set_condition("P", 0.5)
            .set_condition("lnacr(o)", -400)
            .set_phase_to_dormant(phase)
            .with_reference_state("O", 'GAS', tk, 10000)
            .disable_global_minimization()
        )

        # Generate condition combinations for equilibrium calculations
        k = 150
        list_of_conditions = [(("lnacr(o)", lnacr_o), ("T", tk))
                              for lnacr_o in np.linspace(-60, -5, k)]

        batch_calculation.set_conditions_for_equilibria(list_of_conditions)

        # run a calculation first
        results = batch_calculation.calculate([f"dgm({phase})"], 100)

        return (
            list_of_conditions,
            results.get_values_of(f"dgm({phase})")
        )

# %% [markdown]
# ### Parallelising TC calculation

# %%
start_time = time.time()

# paralleising FullEquil
tk_values = np.arange(0+273.15, 605+273.15, 5)
print("temperature range first and last 5 values: ",
      tk_values[:5], tk_values[-5:])
print("FullEquil processes: ", len(tk_values))

# parallelising Gmin and DGM
databases_phases = {
    "tcfe13": ["CORUNDUM", "SPINEL", "HALITE", "BCC_A2", "LIQUID"],
    # "tcfe13": ["BCC_A2", "LIQUID"]
}

Gmin_DGM_args = []
for tk in tk_values:
    for db, phases in databases_phases.items():
        for phase in phases:
            Gmin_DGM_args.append((tk, db, phase))

print("args for Gmin/DGM parallelisation: ",
      Gmin_DGM_args[:5])
print("Gmin/DGM processes: ", len(Gmin_DGM_args))

# %%%%% load data or run calculations %%%%%
try:
    with open(basename + "_FullEquil_results.pkl", "rb") as f:
        FullEquil_results = pickle.load(f)
    with open(basename + "_Gmin_results.pkl", "rb") as f:
        Gmin_results = pickle.load(f)
    with open(basename + "_DGM_results.pkl", "rb") as f:
        DGM_results = pickle.load(f)
    print("Loaded saved results.")
except FileNotFoundError:
    print("Saved results not found. Running calculations.")

    # run the large calculation
    with Pool(processes=num_cpus-1) as pool:
        FullEquil_results = pool.map(tc_calculation_FullEquil, tk_values)
        Gmin_results = pool.starmap(tc_calculation_Gmin, Gmin_DGM_args)
        DGM_results = pool.starmap(
            tc_calculation_NormDrivingForce, Gmin_DGM_args)

    # Save the results
    with open(basename + "_FullEquil_results.pkl", "wb") as f:
        pickle.dump(FullEquil_results, f)
    with open(basename + "_Gmin_results.pkl", "wb") as f:
        pickle.dump(Gmin_results, f)
    with open(basename + "_DGM_results.pkl", "wb") as f:
        pickle.dump(DGM_results, f)

# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

elapsed_time = time.time() - start_time
print("Time taken: ", int(elapsed_time), "seconds")
# Out:
# temperature range first and last 5 values:  [273.15 278.15 283.15 288.15 293.15] [853.15 858.15 863.15 868.15 873.15]
# FullEquil processes:  121
# args for Gmin/DGM parallelisation:  [(273.15, 'tcfe13', 'CORUNDUM'), (273.15, 'tcfe13', 'SPINEL'), (273.15, 'tcfe13', 'HALITE'), (273.15, 'tcfe13', 'BCC_A2'), (273.15, 'tcfe13', 'LIQUID')]
# Gmin/DGM processes:  605
# Saved results not found. Running calculations.
# 14:05:04,422 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:04,513 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:04,457 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:04,573 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:04,589 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:04,588 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:04,610 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:04,609 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:04,698 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:04,709 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:04,711 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:04,751 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:04,763 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:04,817 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:05,100 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:05,286 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:05,278 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:05,314 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:05,311 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:05,332 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:05,360 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:05,457 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:05,481 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:05,484 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:05,502 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:05,570 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:05,562 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:05,585 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:05,602 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:05,621 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:05,637 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:05,685 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:05,722 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:05,740 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:05,750 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:05,750 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:05,787 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:05,800 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:05,814 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:05:07,498 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:07,494 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:07,500 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:07,511 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:07,544 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:07,662 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:07,659 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:07,697 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:07,757 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:07,757 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:07,777 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:07,794 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:07,890 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:07,888 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:07,912 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:07,931 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:07,997 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:08,039 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:08,070 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:08,083 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:08,105 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:08,125 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:08,122 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:08,131 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:08,177 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:08,270 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:08,268 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:08,308 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:08,338 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:08,332 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:08,347 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:08,371 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:08,362 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:08,462 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:08,540 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:08,584 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:08,595 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:08,619 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:08,750 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 14:05:17,832 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 14:05:17,833 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 14:05:17,833 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 14:05:17,838 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 14:05:17,838 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 14:05:17,839 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 14:05:17,932 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 14:05:17,839 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 14:05:17,963 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 14:05:17,933 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 14:05:17,933 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 14:05:17,967 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 14:05:17,839 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 14:05:17,839 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 14:05:17,964 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 14:05:17,969 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 14:05:17,965 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 14:05:18,002 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 14:05:17,934 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 14:05:17,970 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 14:05:17,840 [Thread-1] INFO  CalculationEngine:    'B. Sundman, J. Phase Equilib., 12 (1991) 127-140; Fe-O'
#
# 14:05:17,969 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 14:05:18,004 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 14:05:17,934 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 14:05:17,972 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 14:05:17,840 [Thread-1] INFO  CalculationEngine:    'L. Kjellqvist, M. Selleby and B. sundman, CALPHAD, 32 (2008) 577-592; Cr
#
# 14:05:17,841 [Thread-1] INFO  CalculationEngine:        -Fe-Ni-O'
#
# 14:05:18,036 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 14:05:17,972 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 14:05:18,004 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 14:05:17,934 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 14:05:17,969 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 14:05:17,934 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 14:05:18,038 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 14:05:18,049 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 14:05:17,972 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 14:05:17,934 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 14:05:18,008 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 14:05:18,050 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 14:05:17,935 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 14:05:17,972 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 14:05:18,039 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 14:05:17,970 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 14:05:18,009 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 14:05:17,841 [Thread-1] INFO  CalculationEngine:    'M J Assael, J Phys Chem Ref Data 35 (2006) 285; Fe, Al'
#
# 14:05:18,009 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 14:05:18,050 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 14:05:18,043 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 14:05:17,935 [Thread-1] INFO  CalculationEngine:    'B. Sundman, J. Phase Equilib., 12 (1991) 127-140; Fe-O'
#
# 14:05:18,106 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 14:05:18,043 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 14:05:17,842 [Thread-1] INFO  CalculationEngine:    'R Zhang, Thermo-Calc Software AB: assessing the viscosity of molten
#
# 14:05:17,973 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 14:05:17,935 [Thread-1] INFO  CalculationEngine:    'L. Kjellqvist, M. Selleby and B. sundman, CALPHAD, 32 (2008) 577-592; Cr
#
# 14:05:18,054 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 14:05:17,970 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 14:05:18,010 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 14:05:18,109 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 14:05:18,055 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 14:05:18,110 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 14:05:17,842 [Thread-1] INFO  CalculationEngine:        oxides, 2019'
#
# 14:05:17,935 [Thread-1] INFO  CalculationEngine:        -Fe-Ni-O'
#
# 14:05:18,043 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 14:05:17,970 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 14:05:17,973 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 14:05:18,122 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 14:05:18,010 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 14:05:18,010 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 14:05:17,935 [Thread-1] INFO  CalculationEngine:    'M J Assael, J Phys Chem Ref Data 35 (2006) 285; Fe, Al'
#
# 14:05:17,970 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 14:05:18,010 [Thread-1] INFO  CalculationEngine:    'B. Sundman, J. Phase Equilib., 12 (1991) 127-140; Fe-O'
#
# 14:05:17,842 [Thread-1] INFO  CalculationEngine:    'Same or similar interaction as in the corresponding stable phase'
#
# 14:05:18,110 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 14:05:18,146 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 14:05:18,043 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 14:05:17,971 [Thread-1] INFO  CalculationEngine:    'B. Sundman, J. Phase Equilib., 12 (1991) 127-140; Fe-O'
#
# 14:05:18,125 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 14:05:17,973 [Thread-1] INFO  CalculationEngine:    'B. Sundman, J. Phase Equilib., 12 (1991) 127-140; Fe-O'
#
# 14:05:17,842 [Thread-1] INFO  CalculationEngine:    'C.-M. Arvhult, Optimized ELRS
#
# 14:05:18,110 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 14:05:18,148 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 14:05:18,056 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 14:05:18,044 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 14:05:17,843 [Thread-1] INFO  CalculationEngine:         THCD, Thermo-Calc Software. '
#
# 14:05:18,125 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 14:05:17,936 [Thread-1] INFO  CalculationEngine:    'R Zhang, Thermo-Calc Software AB: assessing the viscosity of molten
#
# 14:05:18,167 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 14:05:18,111 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 14:05:18,010 [Thread-1] INFO  CalculationEngine:    'L. Kjellqvist, M. Selleby and B. sundman, CALPHAD, 32 (2008) 577-592; Cr
#
# 14:05:18,148 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 14:05:18,044 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 14:05:17,975 [Thread-1] INFO  CalculationEngine:    'L. Kjellqvist, M. Selleby and B. sundman, CALPHAD, 32 (2008) 577-592; Cr
#
# 14:05:18,170 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 14:05:17,936 [Thread-1] INFO  CalculationEngine:        oxides, 2019'
#
# 14:05:18,111 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 14:05:18,056 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 14:05:18,181 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 14:05:18,125 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 14:05:17,843 [Thread-1] INFO  CalculationEngine:    'H-L Chen, in TCAL7.0, Evaluation and modeling of electrical resistivity
#
# 14:05:18,154 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 14:05:18,170 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 14:05:17,844 [Thread-1] INFO  CalculationEngine:         thermal conductivity'
#
# 14:05:18,011 [Thread-1] INFO  CalculationEngine:        -Fe-Ni-O'
#
# 14:05:17,971 [Thread-1] INFO  CalculationEngine:    'L. Kjellqvist, M. Selleby and B. sundman, CALPHAD, 32 (2008) 577-592; Cr
#
# 14:05:18,044 [Thread-1] INFO  CalculationEngine:    'B. Sundman, J. Phase Equilib., 12 (1991) 127-140; Fe-O'
#
# 14:05:17,936 [Thread-1] INFO  CalculationEngine:    'Same or similar interaction as in the corresponding stable phase'
#
# 14:05:17,975 [Thread-1] INFO  CalculationEngine:        -Fe-Ni-O'
#
# 14:05:18,057 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 14:05:17,936 [Thread-1] INFO  CalculationEngine:    'C.-M. Arvhult, Optimized ELRS
#
# 14:05:18,126 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 14:05:18,111 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 14:05:18,154 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 14:05:18,011 [Thread-1] INFO  CalculationEngine:    'M J Assael, J Phys Chem Ref Data 35 (2006) 285; Fe, Al'
#
# 14:05:17,972 [Thread-1] INFO  CalculationEngine:        -Fe-Ni-O'
#
# 14:05:18,185 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 14:05:18,044 [Thread-1] INFO  CalculationEngine:    'L. Kjellqvist, M. Selleby and B. sundman, CALPHAD, 32 (2008) 577-592; Cr
#
# 14:05:17,975 [Thread-1] INFO  CalculationEngine:    'M J Assael, J Phys Chem Ref Data 35 (2006) 285; Fe, Al'
#
# 14:05:18,111 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 14:05:18,057 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 14:05:18,155 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 14:05:18,045 [Thread-1] INFO  CalculationEngine:        -Fe-Ni-O'
#
# 14:05:18,175 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 14:05:18,045 [Thread-1] INFO  CalculationEngine:    'M J Assael, J Phys Chem Ref Data 35 (2006) 285; Fe, Al'
#
# 14:05:18,126 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 14:05:17,844 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software, 2020: ELRS/THCD of liquid'
#
# 14:05:18,057 [Thread-1] INFO  CalculationEngine:    'B. Sundman, J. Phase Equilib., 12 (1991) 127-140; Fe-O'
#
# 14:05:17,972 [Thread-1] INFO  CalculationEngine:    'M J Assael, J Phys Chem Ref Data 35 (2006) 285; Fe, Al'
#
# 14:05:18,111 [Thread-1] INFO  CalculationEngine:    'B. Sundman, J. Phase Equilib., 12 (1991) 127-140; Fe-O'
#
# 14:05:18,012 [Thread-1] INFO  CalculationEngine:    'R Zhang, Thermo-Calc Software AB: assessing the viscosity of molten
#
# 14:05:17,936 [Thread-1] INFO  CalculationEngine:         THCD, Thermo-Calc Software. '
#
# 14:05:18,175 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 14:05:18,155 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 14:05:18,126 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 14:05:17,975 [Thread-1] INFO  CalculationEngine:    'R Zhang, Thermo-Calc Software AB: assessing the viscosity of molten
#
# 14:05:18,045 [Thread-1] INFO  CalculationEngine:    'R Zhang, Thermo-Calc Software AB: assessing the viscosity of molten
#
# 14:05:17,844 [Thread-1] INFO  CalculationEngine:    'H-L Chen, Default value for thermal conductivity'
#
# 14:05:17,972 [Thread-1] INFO  CalculationEngine:    'R Zhang, Thermo-Calc Software AB: assessing the viscosity of molten
#
# 14:05:18,012 [Thread-1] INFO  CalculationEngine:        oxides, 2019'
#
# 14:05:17,980 [Thread-1] INFO  CalculationEngine:        oxides, 2019'
#
# 14:05:18,155 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 14:05:18,126 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 14:05:18,112 [Thread-1] INFO  CalculationEngine:    'L. Kjellqvist, M. Selleby and B. sundman, CALPHAD, 32 (2008) 577-592; Cr
#
# 14:05:17,844 [Thread-1] INFO  CalculationEngine:    'H-L Chen, Default value for electrical resistivity'
#
# 14:05:18,046 [Thread-1] INFO  CalculationEngine:        oxides, 2019'
#
# 14:05:17,973 [Thread-1] INFO  CalculationEngine:        oxides, 2019'
#
# 14:05:18,057 [Thread-1] INFO  CalculationEngine:    'L. Kjellqvist, M. Selleby and B. sundman, CALPHAD, 32 (2008) 577-592; Cr
#
# 14:05:17,936 [Thread-1] INFO  CalculationEngine:    'H-L Chen, in TCAL7.0, Evaluation and modeling of electrical resistivity
#
# 14:05:18,176 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 14:05:17,980 [Thread-1] INFO  CalculationEngine:    'Same or similar interaction as in the corresponding stable phase'
#
# 14:05:18,112 [Thread-1] INFO  CalculationEngine:        -Fe-Ni-O'
#
# 14:05:18,155 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 14:05:17,845 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB (2020): assessing the surface tension
#
# 14:05:18,127 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 14:05:17,973 [Thread-1] INFO  CalculationEngine:    'Same or similar interaction as in the corresponding stable phase'
#
# 14:05:18,012 [Thread-1] INFO  CalculationEngine:    'Same or similar interaction as in the corresponding stable phase'
#
# 14:05:18,046 [Thread-1] INFO  CalculationEngine:    'Same or similar interaction as in the corresponding stable phase'
#
# 14:05:17,845 [Thread-1] INFO  CalculationEngine:        of metallic liquid'
#
# 14:05:18,187 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 14:05:18,046 [Thread-1] INFO  CalculationEngine:    'C.-M. Arvhult, Optimized ELRS
#
# 14:05:18,155 [Thread-1] INFO  CalculationEngine:    'B. Sundman, J. Phase Equilib., 12 (1991) 127-140; Fe-O'
#
# 14:05:18,112 [Thread-1] INFO  CalculationEngine:    'M J Assael, J Phys Chem Ref Data 35 (2006) 285; Fe, Al'
#
# 14:05:18,058 [Thread-1] INFO  CalculationEngine:        -Fe-Ni-O'
#
# 14:05:18,127 [Thread-1] INFO  CalculationEngine:    'B. Sundman, J. Phase Equilib., 12 (1991) 127-140; Fe-O'
#
# 14:05:17,937 [Thread-1] INFO  CalculationEngine:         thermal conductivity'
#
# 14:05:17,980 [Thread-1] INFO  CalculationEngine:    'C.-M. Arvhult, Optimized ELRS
#
# 14:05:18,047 [Thread-1] INFO  CalculationEngine:         THCD, Thermo-Calc Software. '
#
# 14:05:18,176 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 14:05:18,012 [Thread-1] INFO  CalculationEngine:    'C.-M. Arvhult, Optimized ELRS
#
# 14:05:18,193 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 14:05:18,013 [Thread-1] INFO  CalculationEngine:         THCD, Thermo-Calc Software. '
#
# 14:05:18,127 [Thread-1] INFO  CalculationEngine:    'L. Kjellqvist, M. Selleby and B. sundman, CALPHAD, 32 (2008) 577-592; Cr
#
# 14:05:18,112 [Thread-1] INFO  CalculationEngine:    'R Zhang, Thermo-Calc Software AB: assessing the viscosity of molten
#
# 14:05:18,176 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 14:05:18,193 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 14:05:17,845 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden 2023; Reassessment of surface
#
# 14:05:18,058 [Thread-1] INFO  CalculationEngine:    'M J Assael, J Phys Chem Ref Data 35 (2006) 285; Fe, Al'
#
# 14:05:18,047 [Thread-1] INFO  CalculationEngine:    'H-L Chen, in TCAL7.0, Evaluation and modeling of electrical resistivity
#
# 14:05:18,156 [Thread-1] INFO  CalculationEngine:    'L. Kjellqvist, M. Selleby and B. sundman, CALPHAD, 32 (2008) 577-592; Cr
#
# 14:05:17,980 [Thread-1] INFO  CalculationEngine:         THCD, Thermo-Calc Software. '
#
# 14:05:18,300 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 14:05:18,013 [Thread-1] INFO  CalculationEngine:    'H-L Chen, in TCAL7.0, Evaluation and modeling of electrical resistivity
#
# 14:05:18,058 [Thread-1] INFO  CalculationEngine:    'R Zhang, Thermo-Calc Software AB: assessing the viscosity of molten
#
# 14:05:17,937 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software, 2020: ELRS/THCD of liquid'
#
# 14:05:18,047 [Thread-1] INFO  CalculationEngine:         thermal conductivity'
#
# 14:05:17,845 [Thread-1] INFO  CalculationEngine:        tension using RK rule'
#
# 14:05:18,302 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 14:05:18,156 [Thread-1] INFO  CalculationEngine:        -Fe-Ni-O'
#
# 14:05:18,013 [Thread-1] INFO  CalculationEngine:         thermal conductivity'
#
# 14:05:18,176 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 14:05:17,937 [Thread-1] INFO  CalculationEngine:    'H-L Chen, Default value for thermal conductivity'
#
# 14:05:17,846 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Surface tensions for oxide liquid in TCOX, Thermo-Calc Software
#
# 14:05:18,127 [Thread-1] INFO  CalculationEngine:        -Fe-Ni-O'
#
# 14:05:18,059 [Thread-1] INFO  CalculationEngine:        oxides, 2019'
#
# 14:05:18,048 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software, 2020: ELRS/THCD of liquid'
#
# 14:05:18,014 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software, 2020: ELRS/THCD of liquid'
#
# 14:05:18,157 [Thread-1] INFO  CalculationEngine:    'M J Assael, J Phys Chem Ref Data 35 (2006) 285; Fe, Al'
#
# 14:05:18,113 [Thread-1] INFO  CalculationEngine:        oxides, 2019'
#
# 14:05:18,302 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 14:05:18,194 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 14:05:17,981 [Thread-1] INFO  CalculationEngine:    'H-L Chen, in TCAL7.0, Evaluation and modeling of electrical resistivity
#
# 14:05:17,847 [Thread-1] INFO  CalculationEngine:        AB, Sweden, 2020-2022'
#
# 14:05:17,937 [Thread-1] INFO  CalculationEngine:    'H-L Chen, Default value for electrical resistivity'
#
# 14:05:18,177 [Thread-1] INFO  CalculationEngine:    'B. Sundman, J. Phase Equilib., 12 (1991) 127-140; Fe-O'
#
# 14:05:18,128 [Thread-1] INFO  CalculationEngine:    'M J Assael, J Phys Chem Ref Data 35 (2006) 285; Fe, Al'
#
# 14:05:17,973 [Thread-1] INFO  CalculationEngine:    'C.-M. Arvhult, Optimized ELRS
#
# 14:05:18,194 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 14:05:18,048 [Thread-1] INFO  CalculationEngine:    'H-L Chen, Default value for thermal conductivity'
#
# 14:05:17,937 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB (2020): assessing the surface tension
#
# 14:05:18,307 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 14:05:17,981 [Thread-1] INFO  CalculationEngine:         thermal conductivity'
#
# 14:05:18,177 [Thread-1] INFO  CalculationEngine:    'L. Kjellqvist, M. Selleby and B. sundman, CALPHAD, 32 (2008) 577-592; Cr
#
# 14:05:18,059 [Thread-1] INFO  CalculationEngine:    'Same or similar interaction as in the corresponding stable phase'
#
# 14:05:18,014 [Thread-1] INFO  CalculationEngine:    'H-L Chen, Default value for thermal conductivity'
#
# 14:05:18,128 [Thread-1] INFO  CalculationEngine:    'R Zhang, Thermo-Calc Software AB: assessing the viscosity of molten
#
# 14:05:18,157 [Thread-1] INFO  CalculationEngine:    'R Zhang, Thermo-Calc Software AB: assessing the viscosity of molten
#
# 14:05:17,938 [Thread-1] INFO  CalculationEngine:        of metallic liquid'
#
# 14:05:18,113 [Thread-1] INFO  CalculationEngine:    'Same or similar interaction as in the corresponding stable phase'
#
# 14:05:18,128 [Thread-1] INFO  CalculationEngine:        oxides, 2019'
#
# 14:05:18,158 [Thread-1] INFO  CalculationEngine:        oxides, 2019'
#
# 14:05:17,981 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software, 2020: ELRS/THCD of liquid'
#
# 14:05:18,014 [Thread-1] INFO  CalculationEngine:    'H-L Chen, Default value for electrical resistivity'
#
# 14:05:17,974 [Thread-1] INFO  CalculationEngine:         THCD, Thermo-Calc Software. '
#
# 14:05:18,048 [Thread-1] INFO  CalculationEngine:    'H-L Chen, Default value for electrical resistivity'
#
# 14:05:18,158 [Thread-1] INFO  CalculationEngine:    'Same or similar interaction as in the corresponding stable phase'
#
# 14:05:18,307 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 14:05:18,178 [Thread-1] INFO  CalculationEngine:        -Fe-Ni-O'
#
# 14:05:18,369 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 14:05:18,195 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 14:05:18,194 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 14:05:18,308 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 14:05:17,938 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden 2023; Reassessment of surface
#
# 14:05:17,981 [Thread-1] INFO  CalculationEngine:    'H-L Chen, Default value for thermal conductivity'
#
# 14:05:18,128 [Thread-1] INFO  CalculationEngine:    'Same or similar interaction as in the corresponding stable phase'
#
# 14:05:18,178 [Thread-1] INFO  CalculationEngine:    'M J Assael, J Phys Chem Ref Data 35 (2006) 285; Fe, Al'
#
# 14:05:17,974 [Thread-1] INFO  CalculationEngine:    'H-L Chen, in TCAL7.0, Evaluation and modeling of electrical resistivity
#
# 14:05:18,373 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 14:05:18,178 [Thread-1] INFO  CalculationEngine:    'R Zhang, Thermo-Calc Software AB: assessing the viscosity of molten
#
# 14:05:18,113 [Thread-1] INFO  CalculationEngine:    'C.-M. Arvhult, Optimized ELRS
#
# 14:05:18,308 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 14:05:18,059 [Thread-1] INFO  CalculationEngine:    'C.-M. Arvhult, Optimized ELRS
#
# 14:05:18,129 [Thread-1] INFO  CalculationEngine:    'C.-M. Arvhult, Optimized ELRS
#
# 14:05:18,195 [Thread-1] INFO  CalculationEngine:    'B. Sundman, J. Phase Equilib., 12 (1991) 127-140; Fe-O'
#
# 14:05:17,981 [Thread-1] INFO  CalculationEngine:    'H-L Chen, Default value for electrical resistivity'
#
# 14:05:17,974 [Thread-1] INFO  CalculationEngine:         thermal conductivity'
#
# 14:05:18,048 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB (2020): assessing the surface tension
#
# 14:05:18,060 [Thread-1] INFO  CalculationEngine:         THCD, Thermo-Calc Software. '
#
# 14:05:18,014 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB (2020): assessing the surface tension
#
# 14:05:18,158 [Thread-1] INFO  CalculationEngine:    'C.-M. Arvhult, Optimized ELRS
#
# 14:05:18,113 [Thread-1] INFO  CalculationEngine:         THCD, Thermo-Calc Software. '
#
# 14:05:18,049 [Thread-1] INFO  CalculationEngine:        of metallic liquid'
#
# 14:05:18,395 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 14:05:18,060 [Thread-1] INFO  CalculationEngine:    'H-L Chen, in TCAL7.0, Evaluation and modeling of electrical resistivity
#
# 14:05:18,308 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 14:05:18,129 [Thread-1] INFO  CalculationEngine:         THCD, Thermo-Calc Software. '
#
# 14:05:17,975 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software, 2020: ELRS/THCD of liquid'
#
# 14:05:18,113 [Thread-1] INFO  CalculationEngine:    'H-L Chen, in TCAL7.0, Evaluation and modeling of electrical resistivity
#
# 14:05:17,982 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB (2020): assessing the surface tension
#
# 14:05:18,049 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden 2023; Reassessment of surface
#
# 14:05:17,938 [Thread-1] INFO  CalculationEngine:        tension using RK rule'
#
# 14:05:18,159 [Thread-1] INFO  CalculationEngine:         THCD, Thermo-Calc Software. '
#
# 14:05:18,178 [Thread-1] INFO  CalculationEngine:        oxides, 2019'
#
# 14:05:18,308 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 14:05:18,395 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 14:05:18,015 [Thread-1] INFO  CalculationEngine:        of metallic liquid'
#
# 14:05:18,195 [Thread-1] INFO  CalculationEngine:    'L. Kjellqvist, M. Selleby and B. sundman, CALPHAD, 32 (2008) 577-592; Cr
#
# 14:05:17,982 [Thread-1] INFO  CalculationEngine:        of metallic liquid'
#
# 14:05:18,060 [Thread-1] INFO  CalculationEngine:         thermal conductivity'
#
# 14:05:18,443 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 14:05:18,049 [Thread-1] INFO  CalculationEngine:        tension using RK rule'
#
# 14:05:18,129 [Thread-1] INFO  CalculationEngine:    'H-L Chen, in TCAL7.0, Evaluation and modeling of electrical resistivity
#
# 14:05:18,199 [Thread-1] INFO  CalculationEngine:        -Fe-Ni-O'
#
# 14:05:18,159 [Thread-1] INFO  CalculationEngine:    'H-L Chen, in TCAL7.0, Evaluation and modeling of electrical resistivity
#
# 14:05:18,114 [Thread-1] INFO  CalculationEngine:         thermal conductivity'
#
# 14:05:17,938 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Surface tensions for oxide liquid in TCOX, Thermo-Calc Software
#
# 14:05:18,015 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden 2023; Reassessment of surface
#
# 14:05:17,992 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden 2023; Reassessment of surface
#
# 14:05:18,396 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 14:05:18,179 [Thread-1] INFO  CalculationEngine:    'Same or similar interaction as in the corresponding stable phase'
#
# 14:05:18,309 [Thread-1] INFO  CalculationEngine:    'B. Sundman, J. Phase Equilib., 12 (1991) 127-140; Fe-O'
#
# 14:05:18,114 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software, 2020: ELRS/THCD of liquid'
#
# 14:05:18,015 [Thread-1] INFO  CalculationEngine:        tension using RK rule'
#
# 14:05:18,050 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Surface tensions for oxide liquid in TCOX, Thermo-Calc Software
#
# 14:05:17,975 [Thread-1] INFO  CalculationEngine:    'H-L Chen, Default value for thermal conductivity'
#
# 14:05:18,445 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 14:05:18,130 [Thread-1] INFO  CalculationEngine:         thermal conductivity'
#
# 14:05:18,159 [Thread-1] INFO  CalculationEngine:         thermal conductivity'
#
# 14:05:18,396 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 14:05:18,199 [Thread-1] INFO  CalculationEngine:    'M J Assael, J Phys Chem Ref Data 35 (2006) 285; Fe, Al'
#
# 14:05:18,114 [Thread-1] INFO  CalculationEngine:    'H-L Chen, Default value for thermal conductivity'
#
# 14:05:17,992 [Thread-1] INFO  CalculationEngine:        tension using RK rule'
#
# 14:05:18,060 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software, 2020: ELRS/THCD of liquid'
#
# 14:05:18,159 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software, 2020: ELRS/THCD of liquid'
#
# 14:05:18,309 [Thread-1] INFO  CalculationEngine:    'L. Kjellqvist, M. Selleby and B. sundman, CALPHAD, 32 (2008) 577-592; Cr
#
# 14:05:17,975 [Thread-1] INFO  CalculationEngine:    'H-L Chen, Default value for electrical resistivity'
#
# 14:05:18,179 [Thread-1] INFO  CalculationEngine:    'C.-M. Arvhult, Optimized ELRS
#
# 14:05:18,445 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 14:05:18,051 [Thread-1] INFO  CalculationEngine:        AB, Sweden, 2020-2022'
#
# 14:05:18,115 [Thread-1] INFO  CalculationEngine:    'H-L Chen, Default value for electrical resistivity'
#
# 14:05:17,993 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Surface tensions for oxide liquid in TCOX, Thermo-Calc Software
#
# 14:05:18,130 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software, 2020: ELRS/THCD of liquid'
#
# 14:05:18,199 [Thread-1] INFO  CalculationEngine:    'R Zhang, Thermo-Calc Software AB: assessing the viscosity of molten
#
# 14:05:17,938 [Thread-1] INFO  CalculationEngine:        AB, Sweden, 2020-2022'
#
# 14:05:18,061 [Thread-1] INFO  CalculationEngine:    'H-L Chen, Default value for thermal conductivity'
#
# 14:05:18,016 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Surface tensions for oxide liquid in TCOX, Thermo-Calc Software
#
# 14:05:18,160 [Thread-1] INFO  CalculationEngine:    'H-L Chen, Default value for thermal conductivity'
#
# 14:05:18,396 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 14:05:17,994 [Thread-1] INFO  CalculationEngine:        AB, Sweden, 2020-2022'
#
# 14:05:18,450 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 14:05:18,200 [Thread-1] INFO  CalculationEngine:        oxides, 2019'
#
# 14:05:18,180 [Thread-1] INFO  CalculationEngine:         THCD, Thermo-Calc Software. '
#
# 14:05:18,130 [Thread-1] INFO  CalculationEngine:    'H-L Chen, Default value for thermal conductivity'
#
# 14:05:18,310 [Thread-1] INFO  CalculationEngine:        -Fe-Ni-O'
#
# 14:05:18,017 [Thread-1] INFO  CalculationEngine:        AB, Sweden, 2020-2022'
#
# 14:05:18,200 [Thread-1] INFO  CalculationEngine:    'Same or similar interaction as in the corresponding stable phase'
#
# 14:05:17,975 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB (2020): assessing the surface tension
#
# 14:05:18,115 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB (2020): assessing the surface tension
#
# 14:05:18,450 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 14:05:18,522 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 14:05:18,160 [Thread-1] INFO  CalculationEngine:    'H-L Chen, Default value for electrical resistivity'
#
# 14:05:18,130 [Thread-1] INFO  CalculationEngine:    'H-L Chen, Default value for electrical resistivity'
#
# 14:05:18,180 [Thread-1] INFO  CalculationEngine:    'H-L Chen, in TCAL7.0, Evaluation and modeling of electrical resistivity
#
# 14:05:18,061 [Thread-1] INFO  CalculationEngine:    'H-L Chen, Default value for electrical resistivity'
#
# 14:05:17,976 [Thread-1] INFO  CalculationEngine:        of metallic liquid'
#
# 14:05:18,115 [Thread-1] INFO  CalculationEngine:        of metallic liquid'
#
# 14:05:18,396 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 14:05:18,310 [Thread-1] INFO  CalculationEngine:    'M J Assael, J Phys Chem Ref Data 35 (2006) 285; Fe, Al'
#
# 14:05:18,530 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 14:05:18,061 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB (2020): assessing the surface tension
#
# 14:05:18,160 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB (2020): assessing the surface tension
#
# 14:05:18,451 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 14:05:18,524 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 14:05:18,533 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 14:05:18,396 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 14:05:18,180 [Thread-1] INFO  CalculationEngine:         thermal conductivity'
#
# 14:05:18,160 [Thread-1] INFO  CalculationEngine:        of metallic liquid'
#
# 14:05:17,976 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden 2023; Reassessment of surface
#
# 14:05:18,200 [Thread-1] INFO  CalculationEngine:    'C.-M. Arvhult, Optimized ELRS
#
# 14:05:18,451 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 14:05:18,131 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB (2020): assessing the surface tension
#
# 14:05:18,161 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden 2023; Reassessment of surface
#
# 14:05:18,180 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software, 2020: ELRS/THCD of liquid'
#
# 14:05:18,451 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 14:05:18,061 [Thread-1] INFO  CalculationEngine:        of metallic liquid'
#
# 14:05:18,310 [Thread-1] INFO  CalculationEngine:    'R Zhang, Thermo-Calc Software AB: assessing the viscosity of molten
#
# 14:05:18,524 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 14:05:18,180 [Thread-1] INFO  CalculationEngine:    'H-L Chen, Default value for thermal conductivity'
#
# 14:05:17,976 [Thread-1] INFO  CalculationEngine:        tension using RK rule'
#
# 14:05:18,451 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 14:05:18,533 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 14:05:18,561 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 14:05:18,201 [Thread-1] INFO  CalculationEngine:         THCD, Thermo-Calc Software. '
#
# 14:05:18,115 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden 2023; Reassessment of surface
#
# 14:05:18,131 [Thread-1] INFO  CalculationEngine:        of metallic liquid'
#
# 14:05:18,161 [Thread-1] INFO  CalculationEngine:        tension using RK rule'
#
# 14:05:18,575 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 14:05:17,977 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Surface tensions for oxide liquid in TCOX, Thermo-Calc Software
#
# 14:05:18,116 [Thread-1] INFO  CalculationEngine:        tension using RK rule'
#
# 14:05:18,181 [Thread-1] INFO  CalculationEngine:    'H-L Chen, Default value for electrical resistivity'
#
# 14:05:18,529 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 14:05:18,397 [Thread-1] INFO  CalculationEngine:    'B. Sundman, J. Phase Equilib., 12 (1991) 127-140; Fe-O'
#
# 14:05:18,538 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 14:05:18,131 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden 2023; Reassessment of surface
#
# 14:05:18,530 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 14:05:18,182 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB (2020): assessing the surface tension
#
# 14:05:18,062 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden 2023; Reassessment of surface
#
# 14:05:18,201 [Thread-1] INFO  CalculationEngine:    'H-L Chen, in TCAL7.0, Evaluation and modeling of electrical resistivity
#
# 14:05:17,978 [Thread-1] INFO  CalculationEngine:        AB, Sweden, 2020-2022'
#
# 14:05:18,452 [Thread-1] INFO  CalculationEngine:    'B. Sundman, J. Phase Equilib., 12 (1991) 127-140; Fe-O'
#
# 14:05:18,564 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 14:05:18,452 [Thread-1] INFO  CalculationEngine:    'L. Kjellqvist, M. Selleby and B. sundman, CALPHAD, 32 (2008) 577-592; Cr
#
# 14:05:18,539 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 14:05:18,564 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 14:05:18,397 [Thread-1] INFO  CalculationEngine:    'L. Kjellqvist, M. Selleby and B. sundman, CALPHAD, 32 (2008) 577-592; Cr
#
# 14:05:18,310 [Thread-1] INFO  CalculationEngine:        oxides, 2019'
#
# 14:05:18,131 [Thread-1] INFO  CalculationEngine:        tension using RK rule'
#
# 14:05:18,116 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Surface tensions for oxide liquid in TCOX, Thermo-Calc Software
#
# 14:05:18,131 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Surface tensions for oxide liquid in TCOX, Thermo-Calc Software
#
# 14:05:18,201 [Thread-1] INFO  CalculationEngine:         thermal conductivity'
#
# 14:05:18,182 [Thread-1] INFO  CalculationEngine:        of metallic liquid'
#
# 14:05:18,162 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Surface tensions for oxide liquid in TCOX, Thermo-Calc Software
#
# 14:05:18,311 [Thread-1] INFO  CalculationEngine:    'Same or similar interaction as in the corresponding stable phase'
#
# 14:05:18,539 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 14:05:18,539 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 14:05:18,062 [Thread-1] INFO  CalculationEngine:        tension using RK rule'
#
# 14:05:18,577 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 14:05:18,530 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 14:05:18,577 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 14:05:18,569 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 14:05:18,132 [Thread-1] INFO  CalculationEngine:        AB, Sweden, 2020-2022'
#
# 14:05:18,063 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Surface tensions for oxide liquid in TCOX, Thermo-Calc Software
#
# ...
#
# 14:11:06,071 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:06,127 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:06,221 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 14:11:06,458 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:06,510 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:06,537 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:06,565 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 14:11:06,565 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:06,812 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:06,846 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 14:11:06,870 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:11:06,896 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:07,087 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:07,209 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:07,431 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:07,539 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:07,641 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 14:11:07,695 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 14:11:07,804 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:11:07,820 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:07,908 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:07,939 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 14:11:07,955 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:11:08,115 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:11:08,244 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:11:08,242 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:11:08,424 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:11:08,493 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 14:11:08,607 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:08,630 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:08,641 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:11:08,646 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:11:08,662 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:11:08,737 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:11:08,738 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:08,780 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:08,866 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:11:08,904 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:08,984 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:11:09,005 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:09,107 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:11:09,216 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:11:09,229 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 14:11:09,464 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:09,472 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:11:09,538 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:09,597 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:11:09,669 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:11:09,821 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:11:09,933 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:11:10,246 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 14:11:10,288 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:11:10,289 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:10,379 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:10,472 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 14:11:10,551 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:11:10,662 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 14:11:10,740 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:11:10,831 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:11:10,878 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 14:11:10,883 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 14:11:11,083 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 14:11:11,102 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 14:11:11,168 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:11,271 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:11:11,288 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:11,311 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 14:11:11,311 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:11,316 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 14:11:11,395 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:11,444 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:11,461 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 14:11:11,455 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:11:11,518 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:11,589 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 14:11:11,609 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 14:11:11,635 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 14:11:11,671 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:11:11,686 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 14:11:11,907 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:11,973 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:11,993 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:12,091 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 14:11:12,098 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:12,090 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 14:11:12,155 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 14:11:12,211 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:12,245 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:12,313 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:12,340 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:12,353 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 14:11:12,362 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:12,371 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:12,431 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:12,443 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:12,521 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:12,587 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:12,587 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:12,589 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 14:11:12,628 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:12,623 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:12,642 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 14:11:12,698 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 14:11:12,701 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:12,719 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:12,731 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:12,730 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:12,802 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:13,008 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 14:11:13,043 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:13,108 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:13,115 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 14:11:13,164 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:13,231 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:13,360 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:13,380 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 14:11:13,422 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:13,467 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:13,470 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:13,484 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:13,524 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:13,529 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:13,581 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:13,622 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 14:11:13,740 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:13,774 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 14:11:13,788 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:13,809 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:13,849 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:13,934 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 14:11:13,927 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:13,983 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:14,161 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:14,209 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 14:11:14,213 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:14,261 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:14,301 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:14,403 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:14,499 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:14,658 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 14:11:14,711 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# Time taken:  375 seconds

# %% [markdown]
# #### checking results

# %%
# check again how many processes:
print("number of processes - FullEquil: ", len(FullEquil_results))
print("number of processes - Gmin: ", len(Gmin_results))
print("number of processes - DGM: ", len(DGM_results))

# in each process: list_of_conditions+'np(CORUNDUM)'+'np(SPINEL)'+'np(HALITE)'+'np(BCC_A2)'+'np(LIQUID)'
print("#data categories in each process - FullEquil: ",
      len(FullEquil_results[0]))

# in each process: list_of_conditions+'gm(phase)'
print("#data categories in each process - Gmin: ", len(Gmin_results[0]))

# in each process: list_of_conditions+'dgm(phase)'
print("#data categories in each process - DGM: ",  len(DGM_results[0]))

# the data length inside the above outputs categories
print("data length inside - FullEquil: ", len(FullEquil_results[0][0]))
print("data length inside - Gmin: ", len(Gmin_results[0][1]))
print("data length inside - DGM: ", len(DGM_results[0][1]))
# Out:
# number of processes - FullEquil:  121
# number of processes - Gmin:  605
# number of processes - DGM:  605
# #data categories in each process - FullEquil:  6
# #data categories in each process - Gmin:  2
# #data categories in each process - DGM:  2
# data length inside - FullEquil:  150
# data length inside - Gmin:  150
# data length inside - DGM:  150

# %% [markdown]
# ### Unpack the calculation results

# %% [markdown]
# #### Analyse FullEquil results

# %%
# Merge results from different processes
list_of_conditions = [res[0] for res in FullEquil_results]
list_np_CORUNDUM = [res[1] for res in FullEquil_results]
list_np_SPINEL = [res[2] for res in FullEquil_results]
list_np_HALITE = [res[3] for res in FullEquil_results]
list_np_BCC_A2 = [res[4] for res in FullEquil_results]
list_np_LIQUID = [res[5] for res in FullEquil_results]

# print(len(list_of_conditions))

# Flattening the lists
list_of_conditions = [
    item for sublist in list_of_conditions for item in sublist]
list_np_CORUNDUM = [item for sublist in list_np_CORUNDUM for item in sublist]
list_np_SPINEL = [item for sublist in list_np_SPINEL for item in sublist]
list_np_HALITE = [item for sublist in list_np_HALITE for item in sublist]
list_np_BCC_A2 = [item for sublist in list_np_BCC_A2 for item in sublist]
list_np_LIQUID = [item for sublist in list_np_LIQUID for item in sublist]

# print(len(list_of_conditions))

# list_np_FCC_L12_merge = [max(a, b, c) for a, b, c in zip(
#     list_np_FCC_L12, list_np_FCC_L12_1, list_np_FCC_L12_2)]

df_FullEquil = pd.DataFrame(columns=['lnacr_o', 'T', 'np(CORUNDUM)',
                                     'np(SPINEL)', 'np(HALITE)', 'np(BCC_A2)', 'np(LIQUID)'])

# Convert conditions and results to DataFrame
df_FullEquil = pd.DataFrame({
    'lnacr_o': [dict(conditions)['lnacr(o)'] for conditions in list_of_conditions],
    'T': [dict(conditions)['T'] for conditions in list_of_conditions],
    'np(CORUNDUM)': list_np_CORUNDUM,
    'np(SPINEL)': list_np_SPINEL,
    'np(HALITE)': list_np_HALITE,
    'np(BCC_A2)': list_np_BCC_A2,
    'np(LIQUID)': list_np_LIQUID
})

df_FullEquil.to_excel(os.path.join(current_directory,
                                   "tc_df_FullEquil_check.xlsx"), index=False)

display(df_FullEquil.head(3), df_FullEquil.shape)
# Out:
#      lnacr_o       T  np(CORUNDUM)  np(SPINEL)  np(HALITE)  np(BCC_A2)  \
# 0 -60.000000  273.15           1.0         0.0         0.0         0.0
# 1 -59.630872  273.15           1.0         0.0         0.0         0.0
# 2 -59.261745  273.15           1.0         0.0         0.0         0.0
#
#    np(LIQUID)
# 0         0.0
# 1         0.0
# 2         0.0
# (18150, 7)

# %% [markdown]
# #### Analyse Gmin results

# %%
from copy import deepcopy


def process_data(Gmin_DGM_args, Gmin_DGM_results):

    Gmin_gm_values = {}
    Gmin_phase_conditions = {}

    for args, result in zip(Gmin_DGM_args, Gmin_DGM_results):
        tk, db, phase = deepcopy(args)
        conditions, gm_values = deepcopy(result)

        lnacr_o_values = [dict(cond)['lnacr(o)'] for cond in conditions]
        T_values = [dict(cond)['T'] for cond in conditions]

        if phase in Gmin_gm_values:
            Gmin_gm_values[phase].extend(gm_values)
        else:
            Gmin_gm_values[phase] = gm_values

        if phase in Gmin_phase_conditions:
            Gmin_phase_conditions[phase]['lnacr(o)'].extend(lnacr_o_values)
            Gmin_phase_conditions[phase]['T'].extend(T_values)
        else:
            Gmin_phase_conditions[phase] = {
                'lnacr(o)': lnacr_o_values, 'T': T_values}

    return Gmin_gm_values, Gmin_phase_conditions

# %%
phases_list = [phase for db_phases in databases_phases.values()
               for phase in db_phases]
print(phases_list)

print("Length of Gmin_DGM_args:", len(Gmin_DGM_args))
print("Length of Gmin_results:", len(Gmin_results))

Gmin_gm_values, Gmin_phase_conditions = process_data(
    Gmin_DGM_args, Gmin_results)

print("temperature_grid x acc_grid:", 130*250)
print("length of Gmin_gm_values: ", len(Gmin_gm_values['BCC_A2']))

for i, phase in enumerate(phases_list):
    assert Gmin_phase_conditions[phases_list[0]
                                 ] == Gmin_phase_conditions[phase]

Gmin_conditions = Gmin_phase_conditions[phases_list[0]]
print("length of Gmin_conditions: ", len(Gmin_conditions['lnacr(o)']))
# Out:
# ['CORUNDUM', 'SPINEL', 'HALITE', 'BCC_A2', 'LIQUID']
# Length of Gmin_DGM_args: 605
# Length of Gmin_results: 605
# temperature_grid x acc_grid: 32500
# length of Gmin_gm_values:  18150
# length of Gmin_conditions:  18150

# %%
df_Gmin = pd.DataFrame({
    'lnacr_o':  Gmin_conditions['lnacr(o)'],
    'T': Gmin_conditions['T'],
    **{f'gm({phase})': Gmin_gm_values.get(phase, []) for phase in phases_list}
})

df_Gmin.to_excel(os.path.join(current_directory,
                 "tc_df_Gmin_check.xlsx"), index=False)

display(df_Gmin.head(3), df_Gmin.shape)
# Out:
#      lnacr_o       T   gm(CORUNDUM)     gm(SPINEL)     gm(HALITE)  \
# 0 -60.000000  273.15 -169478.687286 -165399.993875 -165434.629564
# 1 -59.630872  273.15 -169478.687286 -165403.624199 -165434.629612
# 2 -59.261745  273.15 -169478.687286 -165404.374245 -165434.629620
#
#     gm(BCC_A2)     gm(LIQUID)
# 0 -24490.49248 -153732.971103
# 1 -25308.13219 -153732.973241
# 2 -26118.02405 -153732.974902
# (18150, 7)

# %% [markdown]
# #### Analyse NormDrivingForce results

# %%
print("Length of Gmin_DGM_args:", len(Gmin_DGM_args))
print("Length of DGM_results:", len(DGM_results))

DGM_dgm_values, DGM_phase_conditions = process_data(
    Gmin_DGM_args, DGM_results)

print("temperature_grid x acc_grid:", 130*250)
print("length of DGM_dgm_values: ", len(DGM_dgm_values['BCC_A2']))

for i, phase in enumerate(phases_list):
    assert DGM_phase_conditions[phases_list[0]
                                ] == DGM_phase_conditions[phase]

DGM_conditions = DGM_phase_conditions[phases_list[0]]
print("length of DGM_conditions: ", len(DGM_conditions['lnacr(o)']))
# Out:
# Length of Gmin_DGM_args: 605
# Length of DGM_results: 605
# temperature_grid x acc_grid: 32500
# length of DGM_dgm_values:  18150
# length of DGM_conditions:  18150

# %%
df_DGM = pd.DataFrame({
    'lnacr_o':  DGM_conditions['lnacr(o)'],
    'T': DGM_conditions['T'],
    **{f'dgm({phase})': DGM_dgm_values.get(phase, []) for phase in phases_list}
})

df_DGM.to_excel(os.path.join(current_directory,
                             "tc_df_DGM_check.xlsx"), index=False)

display(df_DGM.head(3), df_DGM.shape)
# Out:
#      lnacr_o       T  dgm(CORUNDUM)  dgm(SPINEL)  dgm(HALITE)  dgm(BCC_A2)  \
# 0 -60.000000  273.15      68.877640    71.771859    74.319791    91.623922
# 1 -59.630872  273.15      69.073060    71.956423    74.504355    91.134553
# 2 -59.261745  273.15      69.268481    72.140986    74.688918    90.648742
#
#    dgm(LIQUID)
# 0    62.892852
# 1    63.114317
# 2    63.335785
# (18150, 7)

# %% [markdown]
# ### FullEquil: steping at one temperature

# %%
# Filter the dataframe for rows where T is 573.15
filtered_df_FullEquil = df_FullEquil[df_FullEquil['T'] == 573.15]
filtered_df_FullEquil.to_excel(os.path.join(current_directory,
                                            "tc_df_FullEquil_check_filter.xlsx"), index=False)

plt.figure(figsize=(5, 5))
colors = {
    'CORUNDUM': '#48A36D',
    'SPINEL': '#3288BD',
    'HALITE': '#756BB1',
    'BCC_A2': '#E68A00',
    'LIQUID': '#D43E4F'
}
labels_list = ['Hematite', 'Magnetite', 'Wustite', 'BCC Iron', 'Liquid']


plt.plot(filtered_df_FullEquil['lnacr_o'], filtered_df_FullEquil['np(CORUNDUM)'],
         color=colors['CORUNDUM'], label='CORUNDUM')
plt.plot(filtered_df_FullEquil['lnacr_o'], filtered_df_FullEquil['np(SPINEL)'],
         color=colors['SPINEL'], label='SPINEL')
# plt.plot(filtered_df_FullEquil['lnacr_o'], filtered_df_FullEquil['np(HALITE)'],
#          color=colors['HALITE'], label='HALITE')
plt.plot(filtered_df_FullEquil['lnacr_o'], filtered_df_FullEquil['np(BCC_A2)'],
         color=colors['BCC_A2'], label='BCC_A2')
# plt.plot(filtered_df_FullEquil['lnacr_o'], filtered_df_FullEquil['np(LIQUID)'],
#          color=colors['LIQUID'], label='LIQUID')

plt.xlabel('Natural log of oxygen activity')
plt.ylabel('Mole fraction')
plt.grid(True)
plt.legend()
# plt.xlim(-100, -25)
plt.show()

# %% [markdown]
# ### FullEquil: mapping for one phase

# %%
plt.figure(figsize=(5, 5))
plt.scatter(df_FullEquil['lnacr_o'], df_FullEquil['T']-273.15,
            c=df_FullEquil['np(CORUNDUM)'], s=6,  alpha=1)
plt.xlabel(df_FullEquil.columns[0])
plt.ylabel(df_FullEquil.columns[1])
plt.grid(True)
plt.title('check and plotting the Hematite')
plt.show()

# %% [markdown]
# ### FullEquil: Mapping for all phases

# %%
# Splitting the main dataframe into individual dataframes and filtering them
df_FullEquil_CORUNDUM = df_FullEquil[['lnacr_o', 'T', 'np(CORUNDUM)']]
df_FullEquil_CORUNDUM = df_FullEquil_CORUNDUM[
    df_FullEquil_CORUNDUM['np(CORUNDUM)'] >= 0.001]

df_FullEquil_SPINEL = df_FullEquil[['lnacr_o', 'T', 'np(SPINEL)']]
df_FullEquil_SPINEL = df_FullEquil_SPINEL[
    df_FullEquil_SPINEL['np(SPINEL)'] >= 0.001]

df_FullEquil_HALITE = df_FullEquil[['lnacr_o', 'T', 'np(HALITE)']]
df_FullEquil_HALITE = df_FullEquil_HALITE[df_FullEquil_HALITE['np(HALITE)']
                                          >= 0.001]

df_FullEquil_BCC_A2 = df_FullEquil[['lnacr_o', 'T', 'np(BCC_A2)']]
df_FullEquil_BCC_A2 = df_FullEquil_BCC_A2[df_FullEquil_BCC_A2['np(BCC_A2)']
                                          >= 0.001]

df_FullEquil_LIQUID = df_FullEquil[['lnacr_o', 'T', 'np(LIQUID)']]
df_FullEquil_LIQUID = df_FullEquil_LIQUID[df_FullEquil_LIQUID['np(LIQUID)']
                                          >= 0.001]

# %%
# Plotting the individual dataframes
plt.figure(figsize=(5, 5))

for i, phase in enumerate(phases_list):
    if phase == "HALITE" or phase == "LIQUID":
        pass
    else:
        df = globals()[f'df_FullEquil_{phase}']
        plt.scatter(df['lnacr_o'], df['T']-273.15, s=12,
                    label=labels_list[i],
                    color=colors[phase], alpha=1)
plt.scatter([-7.9663978], [300], color='white')
plt.xlabel('Natural log of oxygen activity', fontsize=14)
plt.ylabel(r'T ($^\circ$C)', fontsize=14)
plt.title('Full Equilibrium', fontsize=14)
plt.legend(fontsize=12, loc='upper left',
           facecolor='white', edgecolor='black', framealpha=0.9)
plt.grid(True, which='both', linestyle='--', linewidth=0.4)
plt.xlim([min(df_Gmin['lnacr_o']), max(df_Gmin['lnacr_o'])])
plt.ylim([min(df_Gmin['T'])-273.15, max(df_Gmin['T'])-273.15])
plt.yticks(range(0, 601, 100))
plt.tight_layout()

plt_output_fname = "_FullEquil.png"
plt.savefig(os.path.join(current_directory, output_fname+plt_output_fname),
            format='png', dpi=300,  bbox_inches='tight', )
plt.show()

# %% [markdown]
# ### Gmin: mapping for individual phase

# %%
display(df_Gmin.head(3), df_Gmin.shape)
# Out:
#      lnacr_o       T   gm(CORUNDUM)     gm(SPINEL)     gm(HALITE)  \
# 0 -60.000000  273.15 -169478.687286 -165399.993875 -165434.629564
# 1 -59.630872  273.15 -169478.687286 -165403.624199 -165434.629612
# 2 -59.261745  273.15 -169478.687286 -165404.374245 -165434.629620
#
#     gm(BCC_A2)     gm(LIQUID)
# 0 -24490.49248 -153732.971103
# 1 -25308.13219 -153732.973241
# 2 -26118.02405 -153732.974902
# (18150, 7)

# %%
from matplotlib.ticker import ScalarFormatter

# Switch to control whether to use defined range for colorbar
use_defined_range = True

# Define the colormaps and colorbar limits for each phase
# colormaps = {
#     'CORUNDUM': ('Greens', -1.9e5, -1.7e5),
#     'SPINEL':   ('Blues', -1.85e5, -1.55e5),
#     'HALITE':   ('Purples', -1.85e5, -1.5e5),
#     'BCC_A2':   ('YlOrBr', -9e4, -1e4),
#     'LIQUID':   ('RdPu', -2e5, 0.5e5)
# }

colormaps = {
    'CORUNDUM': ('Greens',  -1.85e5, -1.5e5),
    'SPINEL':   ('Blues',   -1.85e5, -1.5e5),
    'HALITE':   ('Purples', -1.85e5, -1.5e5),
    'BCC_A2':   ('YlOrBr',  -9e4, -1e4),
    'LIQUID':   ('RdPu',    -1.85e5, -1.5e5),
}


# Create a new figure with subplots
fig, axs = plt.subplots(nrows=1, ncols=len(phases_list), figsize=(
    3.1 * len(phases_list), 3), sharex=True, sharey=True)

for i, phase in enumerate(phases_list):
    cmap, vmin, vmax = colormaps[phase]

    if use_defined_range:
        sc = axs[i].scatter(df_Gmin['lnacr_o'], df_Gmin['T']-273.15,
                            c=df_Gmin[f'gm({phase})'],
                            cmap=cmap, s=5, alpha=0.6, vmin=vmin, vmax=vmax)
        axs[i].scatter([-7.9663978], [300], color='white')
    else:
        sc = axs[i].scatter(df_Gmin['lnacr_o'], df_Gmin['T']-273.15,
                            c=df_Gmin[f'gm({phase})'],
                            cmap=cmap, s=5, alpha=0.6)
        axs[i].scatter([-7.9663978], [300], color='white')
    cbar = plt.colorbar(sc, ax=axs[i])

    # Change colorbar numbering to scientific notation
    formatter = ScalarFormatter(useMathText=True)
    formatter.set_scientific(True)
    formatter.set_powerlimits((-1, 1))
    cbar.ax.yaxis.set_major_formatter(formatter)

    # Label the colorbar of the last plot only
    if i == len(phases_list) - 1:
        cbar.set_label('molar Gibbs energy (J/mol)', fontsize=14)
    if i == 0:
        axs[i].set_ylabel(r'T ($^\circ$C)', fontsize=14)

    axs[i].set_xlabel('Natural log of oxygen activity', fontsize=14)
    axs[i].set_xlim(-60, -5)
    axs[i].set_ylim(200, 600)
    axs[i].set_xticks(range(-60, -5, 10))
    axs[i].set_yticks(range(200, 601, 100))
    axs[i].grid(True, which='both', linestyle='--', linewidth=0.5)
    axs[i].set_title(f'{labels_list[i]}')
    axs[i].set_aspect('auto', 'box')

plt.tight_layout()
plt_output_fname = "_Gm_phases.png"
# plt.savefig(os.path.join(current_directory, output_fname+plt_output_fname),
#             format='png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Gmin: Mapping for all phases

# %%
columns_to_compare = [f'gm({phase})' for phase in phases_list]

for phase in phases_list:
    column_name = f'gm({phase})'
    condition = df_Gmin[column_name] == df_Gmin[columns_to_compare].min(axis=1)
    globals()[f'df_Gmin_{phase}'] = df_Gmin[condition]

# Plotting the individual dataframes
plt.figure(figsize=(5, 5))

for phase in phases_list:
    df = globals()[f'df_Gmin_{phase}']
    plt.scatter(df['lnacr_o'], df['T'], s=10, label=phase,
                color=colors[phase], alpha=1)

plt.xlabel('Natural log of oxygen activity', fontsize=14)
plt.ylabel(r'T ($^\circ$C)', fontsize=14)
plt.title('minimum Gibbs energy', fontsize=14)
plt.legend(fontsize=12, loc='upper left',
           facecolor='white', edgecolor='black', framealpha=0.9)
plt.grid(True, which='both', linestyle='--', linewidth=0.1)
plt.xlim([min(df_Gmin['lnacr_o']), max(df_Gmin['lnacr_o'])])
plt.ylim([min(df_Gmin['T']), max(df_Gmin['T'])])
plt.tight_layout()


# plt_output_fname = "_Gmin.png"
# plt.savefig(os.path.join(current_directory, output_fname+plt_output_fname),
#             format='png', dpi=300,  bbox_inches='tight')
plt.show()

# %% [markdown]
# ### NormDrivingForce: Mapping for individual phase

# %%
# Create a new figure with subplots
fig, axs = plt.subplots(nrows=1, ncols=len(
    phases_list), figsize=(3.1 * len(phases_list), 3), sharex=True, sharey=True)

colormaps = {
    'CORUNDUM': 'Greens',
    'SPINEL':   'Blues',
    'HALITE':   'Purples',
    'BCC_A2':   'YlOrBr',
    'LIQUID':   'RdPu'
}

for i, phase in enumerate(phases_list):

    sc = axs[i].scatter(df_DGM['lnacr_o'], df_DGM['T'],
                        c=df_DGM[f'dgm({phase})'], cmap=colormaps[phase], s=5, alpha=0.6)

    cbar = plt.colorbar(sc, ax=axs[i])

    # Change colorbar numbering to scientific notation
    formatter = ScalarFormatter(useMathText=True)
    formatter.set_scientific(True)
    formatter.set_powerlimits((-1, 1))
    cbar.ax.yaxis.set_major_formatter(formatter)

    # Label the colorbar of the last plot only
    if i == len(phases_list) - 1:
        cbar.set_label('Driving force normalised by RT', fontsize=14)

    axs[i].set_xlabel('Natural log of oxygen activity', fontsize=14)
    axs[i].set_ylabel(r'T ($^\circ$C)', fontsize=14)
    axs[i].set_xlim([min(df_DGM['lnacr_o']), max(df_DGM['lnacr_o'])])
    axs[i].set_ylim([min(df_DGM['T']), max(df_DGM['T'])])
    axs[i].grid(True, which='both', linestyle='--', linewidth=0.5)
    axs[i].set_title(f'{labels_list[i]}')
    # axs[i].set_aspect('equal', 'box')

plt.tight_layout()
plt_output_fname = "_DGM_phases.png"
plt.savefig(os.path.join(current_directory, output_fname+plt_output_fname),
            format='png', dpi=300,  bbox_inches='tight')
plt.show()

# %%
from utils import plot_phases

func = 'dgm'
# colormaps = {
#     'HEMATITE':  ('Greens',  0, 80),
#     'MAGNETITE': ('Blues',   0, 80),
#     'WUSTITE':   ('Purples', 0, 80),
#     'BCC_A2':    ('YlOrBr',  0, 80),
#     'LIQUID':    ('RdPu',    0, 80)
# }
colormaps = {
    'CORUNDUM': ('coolwarm',  25, 32),
    'SPINEL':   ('coolwarm',  25, 32),
    'HALITE':   ('coolwarm',  25, 32),
    'BCC_A2':   ('coolwarm',  25, 32),
    'LIQUID':   ('coolwarm',  25, 32)
}

use_defined_range = True
cbar_label = 'Driving force normalised by RT'
xlim, ylim, alpha = (-10, -5, 1), (250, 350, 10), 1
s_base, s_highlight = 25, 50
save_plot = False
plt_output_fname = "_DGM_phases.png"
plot_phases(phases_list, df_DGM, func, labels_list,
            colormaps, use_defined_range, cbar_label,
            xlim, ylim, alpha, s_base, s_highlight,
            save_plot, current_directory, output_fname, plt_output_fname)

# %% [markdown]
# ### DGM: Mapping for all phases

# %%
columns_to_compare = [f'dgm({phase})' for phase in phases_list]
# columns_to_compare = ['dgm(SPINEL)', 'dgm(HALITE)']

for phase in phases_list:
    column_name = f'dgm({phase})'
    condition = df_DGM[column_name] == df_DGM[columns_to_compare].max(axis=1)
    globals()[f'df_DGM_{phase}'] = df_DGM[condition]

# Plotting the individual dataframes
plt.figure(figsize=(5, 5))

for i, phase in enumerate(phases_list):
    if phase == 'LIQUID':
        pass
    else:
        df = globals()[f'df_DGM_{phase}']
        plt.scatter(df['lnacr_o'], df['T']-273.15,
                    s=10, label=labels_list[i],
                    color=colors[phase], alpha=0.6)
# plt.scatter([-7.9663978], [300],
#             facecolors='white', edgecolors='black')  # , linewidths=1, s=20)
plt.scatter([-7.9663978], [300], color='white')  # , linewidths=1, s=20)

plt.xlabel('Natural log of oxygen activity', fontsize=14)
plt.ylabel(r'T ($^\circ$C)', fontsize=14)
plt.title('Maximum chemical driving force for nucleation', fontsize=14)
plt.legend(fontsize=12, loc='upper left',
           facecolor='white', edgecolor='black', framealpha=0.9)
plt.grid(True, which='both', linestyle='--', linewidth=0.4)
# plt.xlim([-60, -5])
# plt.ylim([0, 600])
plt.xlim([min(df_Gmin['lnacr_o']), max(df_Gmin['lnacr_o'])])
plt.ylim([min(df_DGM['T'])-273.15, max(df_Gmin['T'])-273.15])
plt.tight_layout()

plt_output_fname = "_DGMmax.png"
plt.savefig(os.path.join(current_directory, output_fname+plt_output_fname),
            format='png', dpi=300,  bbox_inches='tight')
plt.show()

# %%
# columns_to_compare = [f'dgm({phase})' for phase in phases_list]
columns_to_compare = ['dgm(SPINEL)', 'dgm(HALITE)']

for phase in phases_list:
    column_name = f'dgm({phase})'
    condition = df_DGM[column_name] == df_DGM[columns_to_compare].max(axis=1)
    globals()[f'df_DGM_{phase}'] = df_DGM[condition]


# Plotting the individual dataframes
plt.figure(figsize=(5, 5))

for i, phase in enumerate(phases_list):
    if phase == 'LIQUID' or phase == 'CORUNDUM' or phase == 'BCC_A2':
        pass
    else:
        df = globals()[f'df_DGM_{phase}']
        plt.scatter(df['lnacr_o'], df['T']-273.15,
                    s=50, label=labels_list[i],
                    color=colors[phase], alpha=0.6)
plt.scatter([-7.9663978], [300],
            facecolors='white', edgecolors='black', linewidths=1, s=20)

plt.xlabel('Natural log of oxygen activity', fontsize=14)
plt.ylabel(r'T ($^\circ$C)', fontsize=14)
plt.title('Maximum chemical driving force for nucleation', fontsize=14)
plt.legend(fontsize=12, loc='upper left',
           facecolor='white', edgecolor='black', framealpha=0.9)
plt.grid(True, which='both', linestyle='--', linewidth=0.4)
plt.xlim([-20, -5])
plt.ylim([min(df_DGM['T'])-273.15, max(df_DGM['T'])-273.15])
plt.tight_layout()

plt_output_fname = "_DGMmax.png"
plt.savefig(os.path.join(current_directory, output_fname+plt_output_fname),
            format='png', dpi=300,  bbox_inches='tight')
plt.show()
