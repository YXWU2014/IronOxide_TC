# %%
from tc_python import *
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from multiprocessing import Pool
import os
from itertools import product
import time
import matplotlib
matplotlib.rcParams['font.family'] = 'FreeSans'

print(f'cpu_count: {os.cpu_count()}')
# Out:
# cpu_count: 40

# %%
basename = 'Oxide_TC_equilibrium'

current_directory = os.getcwd()
cache_fname = basename + '.ipynb' + "_cache"
output_fname = os.path.splitext(basename)[0]

print("Cache Filename: ", cache_fname)
print("Output Filename: ", output_fname)
print("Current Dir: ", current_directory)
# Out:
# Cache Filename:  Oxide_TC_equilibrium.ipynb_cache
# Output Filename:  Oxide_TC_equilibrium
# Current Dir:  /nethome/home3/yuxiang.wu/Oxide_TC

# %% [markdown]
# ### TC functions
#
# #### `tc_calculation_FullEquil`: compute the equilibrium phase fraction as (acr, T)

# %%
def tc_calculation_FullEquil(tk):
    with TCPython() as start:
        batch_calculation = (
            start
            .set_cache_folder(os.path.join(current_directory, cache_fname))
            .set_ges_version(5)
            .select_database_and_elements("tcfe11", ["Fe", "O"])
            .deselect_phase("*")
            .select_phase("BCC_A2 LIQUID")
            .select_database_and_elements("ssub5", ["Fe", "O"])
            .deselect_phase("*")
            .select_phase("HEMATITE MAGNETITE WUSTITE GAS")
            .get_system()
            .with_batch_equilibrium_calculation()
            .set_condition("T", 100+273.15)
            .set_condition("P", 0.5)
            .set_condition("lnacr(o)", -400)
            .with_reference_state("O", 'GAS', tk, 10000)
            .disable_global_minimization()
        )

        # Generate condition combinations for equilibrium calculations
        k = 250
        list_of_conditions = [(("lnacr(o)", lnacr_o), ("T", tk))
                              for lnacr_o in np.linspace(-80, -5, k)]

        batch_calculation.set_conditions_for_equilibria(list_of_conditions)

        results = batch_calculation.calculate(
            ["np(HEMATITE)", "np(MAGNETITE)", "np(WUSTITE)", "np(BCC_A2)", "np(LIQUID)"], 100)

        return (
            list_of_conditions,
            results.get_values_of('np(HEMATITE)'),
            results.get_values_of('np(MAGNETITE)'),
            results.get_values_of('np(WUSTITE)'),
            results.get_values_of('np(BCC_A2)'),
            results.get_values_of('np(LIQUID)')
        )

# %% [markdown]
# #### `tc_calculation_Gmin`: compute the Gibbs energy as (database, phase, acr, T)

# %%
def tc_calculation_Gmin(tk, db, phase):
    with TCPython() as start:
        batch_calculation = (
            start
            .set_cache_folder(os.path.join(current_directory, cache_fname))
            .set_ges_version(5))

        # Conditional logic to select database and phase
        if db == 'ssub5':
            batch_calculation = (
                batch_calculation
                .select_database_and_elements(db, ["Fe", "O"])
                .deselect_phase("*")
                .select_phase(f"{phase} GAS")
            )
        else:
            batch_calculation = (
                batch_calculation
                .select_database_and_elements(db, ["Fe", "O"])
                .deselect_phase("*")
                .select_phase(phase)
                .select_database_and_elements('ssub5', ["Fe", "O"])
                .deselect_phase("*")
                .select_phase("GAS")
            )

        # Continue with the rest of the method chain
        batch_calculation = (
            batch_calculation
            .get_system()
            .with_batch_equilibrium_calculation()
            .set_condition("T", 100+273.15)
            .set_condition("P", 0.5)
            .set_condition("lnacr(o)", -400)
            .with_reference_state("O", 'GAS', tk, 10000)
            .disable_global_minimization()
        )

        # Generate condition combinations for equilibrium calculations
        k = 250
        list_of_conditions = [(("lnacr(o)", lnacr_o), ("T", tk))
                              for lnacr_o in np.linspace(-80, -5, k)]

        batch_calculation.set_conditions_for_equilibria(list_of_conditions)

        # run a calculation first
        results = batch_calculation.calculate([f"gm({phase})"], 100)

        # # turn "GAS" into Dormant and run the same calculation again
        # batch_calculation.set_phase_to_dormant("GAS")
        # results = batch_calculation.calculate([f"gm({phase})"], 100)

        return (
            list_of_conditions,
            results.get_values_of(f"gm({phase})")
        )

# %% [markdown]
# #### `tc_calculation_NormDrivingForce`: compute the Normalised Driving Force as (database, phase, acr, T)

# %%
def tc_calculation_NormDrivingForce(tk, db, phase):
    with TCPython() as start:
        batch_calculation = (
            start
            .set_cache_folder(os.path.join(current_directory, cache_fname))
            .set_ges_version(5))

        # Conditional logic to select database and phase
        if db == 'ssub5':
            batch_calculation = (
                batch_calculation
                .select_database_and_elements(db, ["Fe", "O"])
                .deselect_phase("*")
                .select_phase(f"{phase} GAS")
            )
        else:
            batch_calculation = (
                batch_calculation
                .select_database_and_elements(db, ["Fe", "O"])
                .deselect_phase("*")
                .select_phase(phase)
                .select_database_and_elements('ssub5', ["Fe", "O"])
                .deselect_phase("*")
                .select_phase("GAS")
            )

        # Continue with the rest of the method chain
        batch_calculation = (
            batch_calculation
            .get_system()
            .with_batch_equilibrium_calculation()
            .set_condition("T", 100+273.15)
            .set_condition("P", 0.5)
            .set_condition("lnacr(o)", -400)
            .set_phase_to_dormant(phase)
            .with_reference_state("O", 'GAS', tk, 10000)
            .disable_global_minimization()
        )

        # Generate condition combinations for equilibrium calculations
        k = 250
        list_of_conditions = [(("lnacr(o)", lnacr_o), ("T", tk))
                              for lnacr_o in np.linspace(-80, -5, k)]

        batch_calculation.set_conditions_for_equilibria(list_of_conditions)

        # run a calculation first
        results = batch_calculation.calculate([f"dgm({phase})"], 100)

        return (
            list_of_conditions,
            results.get_values_of(f"dgm({phase})")
        )

# %% [markdown]
# ### Parallelising TC calculation

# %% [markdown]
# #### Paralleising: FullEquil

# %%
start_time = time.time()

tk_values = np.arange(100+273.15, 1400+273.15, 10)
print("temperature range first and last 5 values: ",
      tk_values[:5], tk_values[-5:])
print("tk_values length - the multi-processes: ", len(tk_values))

with Pool() as pool:
    FullEquil_results = pool.map(tc_calculation_FullEquil, tk_values)

elapsed_time = time.time() - start_time
print("Time taken: ", int(elapsed_time), "seconds")
# Out:
# temperature range first and last 5 values:  [373.15 383.15 393.15 403.15 413.15] [1623.15 1633.15 1643.15 1653.15 1663.15]
# tk_values length - the multi-processes:  130
# 21:32:37,462 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:37,570 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:37,605 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:37,609 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:37,627 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:37,635 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:37,646 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:37,652 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:37,692 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:37,713 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:37,701 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:37,748 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:37,760 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:37,766 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:37,733 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:37,773 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:37,772 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:37,766 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:37,812 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:37,798 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:37,859 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:37,845 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:37,862 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:37,861 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:37,895 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:37,892 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:37,908 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:37,928 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:37,951 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:37,966 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:37,987 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:38,016 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:38,015 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:38,070 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:38,072 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:38,062 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:38,147 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:38,155 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:38,232 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:38,210 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:32:41,004 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,012 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,011 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,022 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,017 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,016 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,036 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,020 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,039 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,024 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,024 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,037 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,039 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,052 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,041 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,062 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,065 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,067 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,079 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,086 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,080 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,057 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,102 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,101 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,096 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,109 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,093 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,090 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,119 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,109 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,124 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,120 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,117 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,118 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,117 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,163 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,148 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,186 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,291 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:41,337 [Thread-1] INFO  CalculationEngine: Opening database::tcfe11::
#
# 21:32:48,385 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 21:32:48,387 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 21:32:48,425 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 21:32:48,388 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 21:32:48,452 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 21:32:48,392 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 21:32:48,426 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 21:32:48,393 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 21:32:48,427 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 21:32:48,478 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 21:32:48,479 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 21:32:48,476 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 21:32:48,454 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 21:32:48,483 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 21:32:48,485 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 21:32:48,481 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 21:32:48,431 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 21:32:48,495 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 21:32:48,497 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 21:32:48,454 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 21:32:48,485 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 21:32:48,495 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 21:32:48,489 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 21:32:48,478 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 21:32:48,393 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 21:32:48,481 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 21:32:48,486 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 21:32:48,509 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 21:32:48,498 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 21:32:48,491 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 21:32:48,487 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 21:32:48,432 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 21:32:48,499 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 21:32:48,485 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 21:32:48,481 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 21:32:48,458 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 21:32:48,487 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 21:32:48,520 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 21:32:48,482 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 21:32:48,479 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 21:32:48,498 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 21:32:48,511 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 21:32:48,493 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 21:32:48,497 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 21:32:48,459 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 21:32:48,522 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 21:32:48,488 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 21:32:48,485 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 21:32:48,487 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 21:32:48,485 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 21:32:48,393 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 21:32:48,499 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 21:32:48,495 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 21:32:48,492 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 21:32:48,459 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 21:32:48,492 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 21:32:48,497 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 21:32:48,502 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 21:32:48,432 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 21:32:48,487 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 21:32:48,549 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 21:32:48,497 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 21:32:48,511 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 21:32:48,548 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 21:32:48,547 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 21:32:48,488 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 21:32:48,433 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 21:32:48,496 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 21:32:48,485 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 21:32:48,492 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 21:32:48,502 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 21:32:48,485 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 21:32:48,486 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 21:32:48,503 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 21:32:48,459 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 21:32:48,557 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 21:32:48,502 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 21:32:48,523 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 21:32:48,548 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 21:32:48,492 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 21:32:48,505 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 21:32:48,561 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 21:32:48,489 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 21:32:48,517 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 21:32:48,549 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 21:32:48,489 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 21:32:48,394 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 21:32:48,493 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 21:32:48,550 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 21:32:48,489 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 21:32:48,558 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 21:32:48,503 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 21:32:48,517 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 21:32:48,502 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 21:32:48,555 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 21:32:48,486 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 21:32:48,550 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 21:32:48,523 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 21:32:48,487 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 21:32:48,502 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 21:32:48,564 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 21:32:48,503 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 21:32:48,486 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 21:32:48,493 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 21:32:48,493 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 21:32:48,558 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 21:32:48,394 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 21:32:48,575 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 21:32:48,502 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 21:32:48,552 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 21:32:48,551 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 21:32:48,486 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 21:32:48,505 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 21:32:48,489 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 21:32:48,497 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 21:32:48,552 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 21:32:48,504 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 21:32:48,578 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 21:32:48,518 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 21:32:48,551 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 21:32:48,498 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 21:32:48,550 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 21:32:48,565 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 21:32:48,599 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 21:32:48,502 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 21:32:48,488 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 21:32:48,558 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 21:32:48,551 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 21:32:48,486 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 21:32:48,506 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 21:32:48,494 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 21:32:48,394 [Thread-1] INFO  CalculationEngine:    'M. J. Assael, J. Phys. Chem. Ref. Data 35 (2006) 285; Fe, Al'
#
# 21:32:48,571 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 21:32:48,562 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 21:32:48,460 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 21:32:48,555 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 21:32:48,523 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 21:32:48,493 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 21:32:48,433 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 21:32:48,506 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 21:32:48,504 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 21:32:48,494 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 21:32:48,558 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 21:32:48,586 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 21:32:48,552 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 21:32:48,558 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 21:32:48,518 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 21:32:48,487 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 21:32:48,460 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 21:32:48,573 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 21:32:48,606 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 21:32:48,563 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 21:32:48,568 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 21:32:48,503 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 21:32:48,394 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden, 2019; Viscosity of liquid
#
# 21:32:48,618 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 21:32:48,503 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 21:32:48,551 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 21:32:48,493 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 21:32:48,608 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 21:32:48,488 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 21:32:48,490 [Thread-1] INFO  CalculationEngine:    'M. J. Assael, J. Phys. Chem. Ref. Data 35 (2006) 285; Fe, Al'
#
# 21:32:48,577 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 21:32:48,586 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 21:32:48,494 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 21:32:48,486 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 21:32:48,602 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 21:32:48,574 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 21:32:48,552 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 21:32:48,395 [Thread-1] INFO  CalculationEngine:        oxides'
#
# 21:32:48,487 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 21:32:48,433 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 21:32:48,503 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 21:32:48,495 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 21:32:48,523 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 21:32:48,503 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 21:32:48,552 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 21:32:48,559 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 21:32:48,559 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 21:32:48,488 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 21:32:48,460 [Thread-1] INFO  CalculationEngine:    'M. J. Assael, J. Phys. Chem. Ref. Data 35 (2006) 285; Fe, Al'
#
# 21:32:48,506 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 21:32:48,552 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 21:32:48,487 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 21:32:48,645 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 21:32:48,608 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 21:32:48,563 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 21:32:48,504 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 21:32:48,623 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 21:32:48,587 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 21:32:48,490 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden, 2019; Viscosity of liquid
#
# 21:32:48,504 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 21:32:48,555 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 21:32:48,574 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 21:32:48,630 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 21:32:48,578 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 21:32:48,603 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 21:32:48,647 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 21:32:48,628 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 21:32:48,553 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 21:32:48,569 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 21:32:48,493 [Thread-1] INFO  CalculationEngine:    'M. J. Assael, J. Phys. Chem. Ref. Data 35 (2006) 285; Fe, Al'
#
# 21:32:48,498 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 21:32:48,518 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 21:32:48,524 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 21:32:48,503 [Thread-1] INFO  CalculationEngine:    'M. J. Assael, J. Phys. Chem. Ref. Data 35 (2006) 285; Fe, Al'
#
# 21:32:48,488 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 21:32:48,461 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden, 2019; Viscosity of liquid
#
# 21:32:48,487 [Thread-1] INFO  CalculationEngine:    'M. J. Assael, J. Phys. Chem. Ref. Data 35 (2006) 285; Fe, Al'
#
# 21:32:48,395 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB: assessing the surface tension of
#
# 21:32:48,487 [Thread-1] INFO  CalculationEngine:    'M. J. Assael, J. Phys. Chem. Ref. Data 35 (2006) 285; Fe, Al'
#
# 21:32:48,574 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 21:32:48,689 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 21:32:48,504 [Thread-1] INFO  CalculationEngine:    'M. J. Assael, J. Phys. Chem. Ref. Data 35 (2006) 285; Fe, Al'
#
# 21:32:48,608 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 21:32:48,623 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 21:32:48,649 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 21:32:48,495 [Thread-1] INFO  CalculationEngine:    'M. J. Assael, J. Phys. Chem. Ref. Data 35 (2006) 285; Fe, Al'
#
# 21:32:48,555 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 21:32:48,504 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 21:32:48,433 [Thread-1] INFO  CalculationEngine:    'M. J. Assael, J. Phys. Chem. Ref. Data 35 (2006) 285; Fe, Al'
#
# 21:32:48,559 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 21:32:48,614 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 21:32:48,560 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 21:32:48,693 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 21:32:48,395 [Thread-1] INFO  CalculationEngine:        metallic liquid'
#
# 21:32:48,503 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden, 2019; Viscosity of liquid
#
# 21:32:48,489 [Thread-1] INFO  CalculationEngine:    'M. J. Assael, J. Phys. Chem. Ref. Data 35 (2006) 285; Fe, Al'
#
# 21:32:48,647 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 21:32:48,563 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 21:32:48,491 [Thread-1] INFO  CalculationEngine:        oxides'
#
# 21:32:48,578 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 21:32:48,504 [Thread-1] INFO  CalculationEngine:        oxides'
#
# 21:32:48,489 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden, 2019; Viscosity of liquid
#
# 21:32:48,615 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 21:32:48,563 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 21:32:48,434 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden, 2019; Viscosity of liquid
#
# 21:32:48,560 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 21:32:48,552 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 21:32:48,629 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 21:32:48,569 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 21:32:48,556 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 21:32:48,615 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 21:32:48,608 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 21:32:48,461 [Thread-1] INFO  CalculationEngine:        oxides'
#
# 21:32:48,504 [Thread-1] INFO  CalculationEngine:    'M. J. Assael, J. Phys. Chem. Ref. Data 35 (2006) 285; Fe, Al'
#
# 21:32:48,435 [Thread-1] INFO  CalculationEngine:        oxides'
#
# 21:32:48,487 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden, 2019; Viscosity of liquid
#
# 21:32:48,560 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 21:32:48,492 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB: assessing the surface tension of
#
# 21:32:48,524 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 21:32:48,498 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 21:32:48,630 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 21:32:48,504 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden, 2019; Viscosity of liquid
#
# 21:32:48,560 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 21:32:48,487 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden, 2019; Viscosity of liquid
#
# 21:32:48,495 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden, 2019; Viscosity of liquid
#
# 21:32:48,579 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 21:32:48,489 [Thread-1] INFO  CalculationEngine:        oxides'
#
# 21:32:48,652 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 21:32:48,492 [Thread-1] INFO  CalculationEngine:        metallic liquid'
#
# 21:32:48,609 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 21:32:48,589 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 21:32:48,552 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 21:32:48,575 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 21:32:48,630 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 21:32:48,556 [Thread-1] INFO  CalculationEngine:    'M. J. Assael, J. Phys. Chem. Ref. Data 35 (2006) 285; Fe, Al'
#
# 21:32:48,559 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 21:32:48,519 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 21:32:48,505 [Thread-1] INFO  CalculationEngine:        oxides'
#
# 21:32:48,663 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 21:32:48,556 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 21:32:48,556 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 21:32:48,560 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 21:32:48,504 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden, 2019; Viscosity of liquid
#
# 21:32:48,490 [Thread-1] INFO  CalculationEngine:        oxides'
#
# 21:32:48,498 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 21:32:48,489 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB: assessing the surface tension of
#
# 21:32:48,496 [Thread-1] INFO  CalculationEngine:        oxides'
#
# 21:32:48,524 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 21:32:48,489 [Thread-1] INFO  CalculationEngine:        metallic liquid'
#
# 21:32:48,630 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 21:32:48,504 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB: assessing the surface tension of
#
# 21:32:48,494 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden, 2019; Viscosity of liquid
#
# 21:32:48,462 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB: assessing the surface tension of
#
# 21:32:48,553 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 21:32:48,609 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 21:32:48,488 [Thread-1] INFO  CalculationEngine:        oxides'
#
# 21:32:48,563 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 21:32:48,615 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 21:32:48,490 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB: assessing the surface tension of
#
# 21:32:48,664 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 21:32:48,579 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 21:32:48,435 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB: assessing the surface tension of
#
# 21:32:48,670 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 21:32:48,524 [Thread-1] INFO  CalculationEngine:    'M. J. Assael, J. Phys. Chem. Ref. Data 35 (2006) 285; Fe, Al'
#
# 21:32:48,506 [Thread-1] INFO  CalculationEngine:        oxides'
#
# 21:32:48,570 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 21:32:48,609 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 21:32:48,553 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 21:32:48,519 [Thread-1] INFO  CalculationEngine:    'M. J. Assael, J. Phys. Chem. Ref. Data 35 (2006) 285; Fe, Al'
#
# 21:32:48,552 [Thread-1] INFO  CalculationEngine:    'M. J. Assael, J. Phys. Chem. Ref. Data 35 (2006) 285; Fe, Al'
#
# 21:32:48,504 [Thread-1] INFO  CalculationEngine:        metallic liquid'
#
# 21:32:48,488 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB: assessing the surface tension of
#
# 21:32:48,615 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 21:32:48,497 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB: assessing the surface tension of
#
# 21:32:48,506 [Thread-1] INFO  CalculationEngine:    'M. J. Assael, J. Phys. Chem. Ref. Data 35 (2006) 285; Fe, Al'
#
# 21:32:48,590 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 21:32:48,495 [Thread-1] INFO  CalculationEngine:        oxides'
#
# 21:32:48,525 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden, 2019; Viscosity of liquid
#
# 21:32:48,499 [Thread-1] INFO  CalculationEngine:    'M. J. Assael, J. Phys. Chem. Ref. Data 35 (2006) 285; Fe, Al'
#
# 21:32:48,435 [Thread-1] INFO  CalculationEngine:        metallic liquid'
#
# 21:32:48,506 [Thread-1] INFO  CalculationEngine:        metallic liquid'
#
# 21:32:48,505 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB: assessing the surface tension of
#
# 21:32:48,589 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 21:32:48,615 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 21:32:48,561 [Thread-1] INFO  CalculationEngine:    'M. J. Assael, J. Phys. Chem. Ref. Data 35 (2006) 285; Fe, Al'
#
# 21:32:48,490 [Thread-1] INFO  CalculationEngine:        metallic liquid'
#
# 21:32:48,462 [Thread-1] INFO  CalculationEngine:        metallic liquid'
#
# 21:32:48,664 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 21:32:48,519 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden, 2019; Viscosity of liquid
#
# 21:32:48,499 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden, 2019; Viscosity of liquid
#
# 21:32:48,575 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 21:32:48,693 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 21:32:48,610 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 21:32:48,575 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 21:32:48,553 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 21:32:48,671 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 21:32:48,506 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden, 2019; Viscosity of liquid
#
# 21:32:48,553 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden, 2019; Viscosity of liquid
#
# 21:32:48,553 [Thread-1] INFO  CalculationEngine:    'M. J. Assael, J. Phys. Chem. Ref. Data 35 (2006) 285; Fe, Al'
#
# 21:32:48,488 [Thread-1] INFO  CalculationEngine:        metallic liquid'
#
# 21:32:48,573 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 21:32:48,630 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 21:32:48,564 [Thread-1] INFO  CalculationEngine:    'M. J. Assael, J. Phys. Chem. Ref. Data 35 (2006) 285; Fe, Al'
#
# 21:32:48,525 [Thread-1] INFO  CalculationEngine:        oxides'
#
# 21:32:48,556 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden, 2019; Viscosity of liquid
#
# 21:32:48,500 [Thread-1] INFO  CalculationEngine:        oxides'
#
# 21:32:48,610 [Thread-1] INFO  CalculationEngine:    'M. J. Assael, J. Phys. Chem. Ref. Data 35 (2006) 285; Fe, Al'
#
# 21:32:48,553 [Thread-1] INFO  CalculationEngine:        oxides'
#
# 21:32:48,561 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden, 2019; Viscosity of liquid
#
# 21:32:48,557 [Thread-1] INFO  CalculationEngine:        oxides'
#
# 21:32:48,520 [Thread-1] INFO  CalculationEngine:        oxides'
#
# 21:32:48,575 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 21:32:48,573 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 21:32:48,712 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 21:32:48,497 [Thread-1] INFO  CalculationEngine:        metallic liquid'
#
# 21:32:48,564 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden, 2019; Viscosity of liquid
#
# 21:32:48,495 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB: assessing the surface tension of
#
# 21:32:48,616 [Thread-1] INFO  CalculationEngine:    'M. J. Assael, J. Phys. Chem. Ref. Data 35 (2006) 285; Fe, Al'
#
# 21:32:48,506 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB: assessing the surface tension of
#
# 21:32:48,671 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 21:32:48,590 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 21:32:48,554 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden, 2019; Viscosity of liquid
#
# 21:32:48,525 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB: assessing the surface tension of
#
# 21:32:48,506 [Thread-1] INFO  CalculationEngine:        oxides'
#
# 21:32:48,665 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 21:32:48,560 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 21:32:48,500 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB: assessing the surface tension of
#
# 21:32:48,665 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 21:32:48,631 [Thread-1] INFO  CalculationEngine:    'M. J. Assael, J. Phys. Chem. Ref. Data 35 (2006) 285; Fe, Al'
#
# 21:32:48,844 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 21:32:48,554 [Thread-1] INFO  CalculationEngine:        oxides'
#
# 21:32:48,565 [Thread-1] INFO  CalculationEngine:        oxides'
#
# 21:32:48,520 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB: assessing the surface tension of
#
# 21:32:48,495 [Thread-1] INFO  CalculationEngine:        metallic liquid'
#
# 21:32:48,617 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden, 2019; Viscosity of liquid
#
# 21:32:48,562 [Thread-1] INFO  CalculationEngine:        oxides'
#
# 21:32:48,506 [Thread-1] INFO  CalculationEngine:        metallic liquid'
#
# 21:32:48,590 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 21:32:48,610 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden, 2019; Viscosity of liquid
#
# 21:32:48,576 [Thread-1] INFO  CalculationEngine:    'M. J. Assael, J. Phys. Chem. Ref. Data 35 (2006) 285; Fe, Al'
#
# 21:32:48,576 [Thread-1] INFO  CalculationEngine:    'M. J. Assael, J. Phys. Chem. Ref. Data 35 (2006) 285; Fe, Al'
#
# 21:32:48,723 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 21:32:48,507 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB: assessing the surface tension of
#
# 21:32:48,560 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 21:32:48,525 [Thread-1] INFO  CalculationEngine:        metallic liquid'
#
# 21:32:48,557 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB: assessing the surface tension of
#
# 21:32:48,672 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 21:32:48,666 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 21:32:48,554 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB: assessing the surface tension of
#
# 21:32:48,500 [Thread-1] INFO  CalculationEngine:        metallic liquid'
#
# 21:32:48,565 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB: assessing the surface tension of
#
# 21:32:48,576 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden, 2019; Viscosity of liquid
#
# 21:32:48,666 [Thread-1] INFO  CalculationEngine:    'M. J. Assael, J. Phys. Chem. Ref. Data 35 (2006) 285; Fe, Al'
#
# 21:32:48,521 [Thread-1] INFO  CalculationEngine:        metallic liquid'
#
# 21:32:48,557 [Thread-1] INFO  CalculationEngine:        metallic liquid'
#
# ...
#
# 21:33:18,857 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:18,928 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:18,953 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:18,945 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:18,976 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:19,027 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:19,030 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:19,056 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:19,108 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:19,143 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:19,226 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 21:33:19,233 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:19,415 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 21:33:19,420 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 21:33:19,534 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 21:33:19,680 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 21:33:19,712 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:19,740 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:19,792 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:19,793 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 21:33:19,862 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:19,855 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:19,856 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:19,859 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:19,849 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:19,957 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:19,945 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:19,953 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:19,979 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:19,971 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:19,985 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:20,031 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:20,061 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:20,072 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:20,060 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 21:33:20,087 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:20,193 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 21:33:20,273 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 21:33:20,292 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:20,404 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:20,492 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:20,503 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 21:33:20,678 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:20,731 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 21:33:20,775 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:20,805 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:20,831 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:20,854 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 21:33:20,883 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:20,882 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:20,898 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:20,902 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:20,962 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:20,974 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:20,981 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:20,991 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:21,011 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 21:33:21,034 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:21,064 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:21,150 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:21,188 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:21,271 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:21,309 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:21,352 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:21,366 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:21,384 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:21,441 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:21,455 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:33:21,456 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:21,485 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:21,505 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:21,562 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:21,631 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:21,663 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:21,664 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:21,668 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:21,714 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:21,717 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:21,733 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:21,766 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:21,777 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:21,801 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:22,104 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:33:23,074 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:33:23,278 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:33:23,359 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 21:33:23,425 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:33:23,481 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:33:23,596 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:33:23,606 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:33:23,674 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:33:23,715 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 21:33:23,928 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:24,010 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:24,058 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 21:33:24,090 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:24,519 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:24,560 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:24,627 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:24,737 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 21:33:25,017 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 21:33:25,059 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 21:33:25,110 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 21:33:25,166 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:25,234 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 21:33:25,242 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:25,299 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 21:33:25,308 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:25,334 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 21:33:25,497 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:25,485 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 21:33:25,568 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:25,567 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:25,610 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:25,632 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:25,637 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:25,659 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:25,693 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:25,702 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:25,711 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:25,762 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:25,798 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:25,804 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:25,841 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:25,906 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:25,934 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:25,958 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:25,999 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:26,000 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:26,022 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 21:33:26,080 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# Time taken:  53 seconds

# %%
# check again how many processes:
print("number of processes: ", len(FullEquil_results))

# in each process: list_of_conditions+'np(HEMATITE)'+'np(MAGNETITE)'+'np(WUSTITE)'+'np(BCC_A2)'+'np(LIQUID)'
print("how many data categories in each process: ", len(FullEquil_results[0]))

# the data length inside the above outputs categories
print("data length inside: ", len(FullEquil_results[0][0]))
# Out:
# number of processes:  130
# how many data categories in each process:  6
# data length inside:  250

# %% [markdown]
# #### Paralleising: Gmin

# %%
start_time = time.time()

tk_values = np.arange(100+273.15, 1400+273.15, 10)

databases_phases = {
    "ssub5": ["HEMATITE", "MAGNETITE", "WUSTITE"],
    "tcfe11": ["BCC_A2", "LIQUID"]
}

Gmin_args = []
for tk in tk_values:
    for db, phases in databases_phases.items():
        for phase in phases:
            Gmin_args.append((tk, db, phase))

print("args for Gmin parallelisation: ",
      Gmin_args[:5])
print(Gmin_args[-5:])
print("args length: ", len(Gmin_args))

with Pool() as pool:
    Gmin_results = pool.starmap(tc_calculation_Gmin, Gmin_args)
    DGM_results = pool.starmap(tc_calculation_NormDrivingForce, Gmin_args)

elapsed_time = time.time() - start_time
print("Time taken: ", int(elapsed_time), "seconds")
# Out:
# args for Gmin parallelisation:  [(373.15, 'ssub5', 'HEMATITE'), (373.15, 'ssub5', 'MAGNETITE'), (373.15, 'ssub5', 'WUSTITE'), (373.15, 'tcfe11', 'BCC_A2'), (373.15, 'tcfe11', 'LIQUID')]
# [(1663.15, 'ssub5', 'HEMATITE'), (1663.15, 'ssub5', 'MAGNETITE'), (1663.15, 'ssub5', 'WUSTITE'), (1663.15, 'tcfe11', 'BCC_A2'), (1663.15, 'tcfe11', 'LIQUID')]
# args length:  650
# 22:23:17,307 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,299 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,387 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,386 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,425 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,433 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,436 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,442 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,458 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,471 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,454 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,501 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,496 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,507 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,529 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,513 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,547 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,554 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,543 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,563 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,568 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,479 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,553 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,566 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,572 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,582 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,590 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,597 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,655 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,683 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,682 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,684 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,710 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,713 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,721 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,739 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,736 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,763 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,876 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:17,925 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:20,944 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:20,925 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:20,967 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:20,960 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:20,974 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:20,960 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:20,977 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:20,982 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:20,987 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:21,002 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:21,005 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:21,001 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:21,015 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:21,018 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:21,022 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:21,014 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:21,016 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:21,027 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:21,028 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:21,018 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:21,046 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:21,003 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:21,034 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:21,034 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:21,065 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:21,065 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:21,053 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:21,063 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:21,044 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:21,077 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:21,074 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:21,081 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:21,095 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:21,092 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:21,100 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:21,093 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:21,107 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:21,187 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:21,288 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:21,578 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:22,617 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:22,804 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:22,812 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:22,854 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:22,890 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:22,914 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:22,940 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:22,948 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:22,973 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:22,957 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:22,970 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:22,979 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:22,866 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:22,964 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:22,993 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:22,998 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:23,030 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:23,006 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:23,059 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:23,050 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:23,043 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:23,070 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:23,093 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:23,070 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:23,103 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:23,111 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:23,127 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:23,141 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:23,164 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:23,140 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:23,223 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:23,184 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:23,139 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:23,240 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:23,337 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:23,332 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:23,442 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:23,496 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:23,483 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:23,864 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:27,347 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:27,366 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:27,889 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:28,626 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:28,886 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:28,942 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:28,962 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:29,091 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:29,163 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:29,321 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:29,548 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:29,583 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:29,678 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:29,736 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:30,185 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:30,194 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:30,341 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:30,388 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:30,553 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:30,590 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:30,778 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:30,833 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:30,857 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:30,999 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:31,206 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:31,257 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:31,275 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:31,341 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:31,367 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:31,515 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:31,562 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:31,650 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:31,740 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:31,736 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:31,914 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:31,906 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:31,937 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:31,943 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:32,047 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:32,120 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:32,272 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:32,424 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:32,498 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:32,541 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:32,552 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:32,592 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:32,859 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:32,944 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:32,968 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:33,048 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:33,145 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:33,149 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:33,159 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:33,162 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:33,172 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:33,309 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:33,405 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:33,516 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:33,523 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:33,550 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:33,636 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:33,712 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:33,754 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:33,761 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:33,772 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:33,919 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:33,959 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:34,068 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:34,131 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:34,164 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:34,197 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:34,288 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:34,367 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:34,375 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:34,513 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:34,618 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:34,669 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:34,731 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:34,769 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:34,816 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:34,860 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:34,931 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:34,979 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:34,998 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:35,064 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:35,060 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:35,075 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:35,233 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:35,397 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:35,527 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:35,624 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:35,648 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:35,638 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:35,648 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:35,683 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:35,883 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:36,061 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:36,101 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:36,128 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:36,128 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:36,159 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:36,177 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:36,313 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:36,330 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:36,487 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:36,719 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:36,725 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:36,726 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:36,733 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:36,762 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:36,835 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:36,940 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:37,001 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:37,159 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:37,219 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:37,235 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:37,244 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:37,262 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:37,579 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:37,673 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:37,807 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:37,842 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:38,085 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:38,208 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:38,229 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:38,551 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:38,653 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:38,728 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:38,777 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:39,098 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:39,309 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:39,341 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:39,520 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:39,533 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:39,874 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:39,880 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:39,982 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:39,987 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:40,020 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:40,390 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:40,439 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:40,470 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:40,528 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:40,650 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:40,778 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:40,864 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:40,995 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:41,046 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:41,096 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:41,141 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:41,206 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:41,185 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:41,275 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:41,485 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:41,495 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:41,517 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:41,656 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:41,762 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:41,824 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:41,936 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:42,024 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:42,081 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:42,100 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:42,200 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:42,213 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:42,278 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:42,401 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:42,477 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:42,497 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:42,682 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:42,726 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:42,782 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:42,839 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:42,895 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:43,229 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:43,287 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:43,349 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:43,367 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:43,488 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:43,484 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:43,518 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:43,541 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:43,600 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:43,681 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:43,741 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:43,777 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:43,874 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:43,974 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:44,030 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:44,144 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:44,169 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:44,217 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:44,251 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:44,285 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:44,345 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:44,403 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:44,393 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:44,507 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:44,563 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:44,634 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:44,699 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:44,707 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:44,760 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:44,792 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:44,822 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:44,869 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:44,997 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:45,125 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:45,154 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:45,261 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:45,429 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:45,457 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:45,475 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:45,614 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:45,797 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:45,817 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:45,957 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:45,975 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:46,080 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:46,143 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:46,167 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:46,202 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:46,214 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:46,309 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:46,473 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:46,497 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:46,539 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:46,797 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:46,844 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:46,910 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:47,063 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:47,083 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:47,133 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:47,136 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:47,212 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:47,249 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:47,405 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:47,434 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:47,569 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:47,627 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:47,793 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:47,866 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:47,961 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:48,089 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:48,118 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:48,263 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:48,272 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:48,268 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:48,530 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:48,568 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:48,767 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:49,009 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:49,027 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:49,264 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:49,504 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:49,714 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:49,736 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:49,802 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:49,959 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:50,106 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:50,264 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:50,281 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:50,455 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:50,483 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:50,540 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:50,560 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:50,678 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:50,786 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:50,797 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:50,915 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:50,931 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:50,955 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:51,016 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:51,032 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:51,231 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:51,364 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:51,372 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:51,383 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:51,454 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:51,508 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:51,659 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:51,656 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:51,812 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:51,850 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:51,880 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:51,926 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:52,029 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:52,088 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:52,189 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:52,343 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:52,347 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:52,431 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:52,658 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:52,871 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:52,900 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:52,992 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:53,115 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:53,127 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:53,218 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:53,323 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:53,355 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:53,355 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:53,415 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:53,593 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:53,634 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:53,633 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:53,740 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:53,763 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:53,801 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:53,817 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:53,941 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:54,045 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:54,123 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:54,138 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:54,235 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:54,254 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:54,315 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:54,376 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:54,424 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:54,581 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:54,587 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:54,699 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:54,742 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:54,777 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:54,774 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:54,833 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:54,850 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:54,924 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:54,950 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:54,981 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:55,062 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:55,090 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:55,389 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:55,554 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:55,620 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:55,848 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:55,932 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:55,997 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:56,064 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:56,079 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:56,087 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:56,096 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:56,107 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:56,113 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:56,183 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:56,497 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:56,568 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:56,649 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:56,724 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:56,767 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:56,917 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:57,077 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:57,096 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 22:23:57,113 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
#
# 22:23:57,150 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:57,273 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 22:23:57,293 [Thread-1] INFO  Calculation: Found matching previous result. BatchEquilibriumCalculation is unnecessary
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /nethome/yuxiang.wu/Oxide_TC/Oxide_TC_equilibrium.ipynb Cell 14 line 2
#      <a href='vscode-notebook-cell://ssh-remote%2Bmaws13.mpie.de/nethome/yuxiang.wu/Oxide_TC/Oxide_TC_equilibrium.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a> print("args length: ", len(Gmin_args))
#      <a href='vscode-notebook-cell://ssh-remote%2Bmaws13.mpie.de/nethome/yuxiang.wu/Oxide_TC/Oxide_TC_equilibrium.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=20'>21</a> with Pool() as pool:
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bmaws13.mpie.de/nethome/yuxiang.wu/Oxide_TC/Oxide_TC_equilibrium.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=21'>22</a>     Gmin_results = pool.starmap(tc_calculation_Gmin, Gmin_args)
#      <a href='vscode-notebook-cell://ssh-remote%2Bmaws13.mpie.de/nethome/yuxiang.wu/Oxide_TC/Oxide_TC_equilibrium.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=22'>23</a>     DGM_results = pool.starmap(tc_calculation_NormDrivingForce, Gmin_args)
#      <a href='vscode-notebook-cell://ssh-remote%2Bmaws13.mpie.de/nethome/yuxiang.wu/Oxide_TC/Oxide_TC_equilibrium.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=24'>25</a> elapsed_time = time.time() - start_time
#
# File ~/anaconda3/envs/tf-env/lib/python3.9/multiprocessing/pool.py:372, in Pool.starmap(self, func, iterable, chunksize)
#     366 def starmap(self, func, iterable, chunksize=None):
#     367     '''
#     368     Like `map()` method but the elements of the `iterable` are expected to
#     369     be iterables as well and will be unpacked as arguments. Hence
#     370     `func` and (a, b) becomes func(a, b).
#     371     '''
# --> 372     return self._map_async(func, iterable, starmapstar, chunksize).get()
#
# File ~/anaconda3/envs/tf-env/lib/python3.9/multiprocessing/pool.py:765, in ApplyResult.get(self, timeout)
#     764 def get(self, timeout=None):
# --> 765     self.wait(timeout)
#     766     if not self.ready():
#     767         raise TimeoutError
#
# File ~/anaconda3/envs/tf-env/lib/python3.9/multiprocessing/pool.py:762, in ApplyResult.wait(self, timeout)
#     761 def wait(self, timeout=None):
# --> 762     self._event.wait(timeout)
#
# File ~/anaconda3/envs/tf-env/lib/python3.9/threading.py:581, in Event.wait(self, timeout)
#     579 signaled = self._flag
#     580 if not signaled:
# --> 581     signaled = self._cond.wait(timeout)
#     582 return signaled
#
# File ~/anaconda3/envs/tf-env/lib/python3.9/threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:

# %%
# check again how many processes:
print("number of processes: ", len(Gmin_results))

# in each process: list_of_conditions+'gm(phase)'
print("how many data categories in each process: ",  len(Gmin_results[0]))

# the data length inside the above outputs categories
print("data length inside: ", len(Gmin_results[0][1]))
# Out:
# number of processes:  650
# how many data categories in each process:  2
# data length inside:  250

# %% [markdown]
# #### Paralleising: NormDrivingForce

# %%
start_time = time.time()

tk_values = np.arange(100+273.15, 1400+273.15, 10)

databases_phases = {
    "ssub5": ["HEMATITE", "MAGNETITE", "WUSTITE"],
    "tcfe11": ["BCC_A2", "LIQUID"]
}

Gmin_args = []
for tk in tk_values:
    for db, phases in databases_phases.items():
        for phase in phases:
            Gmin_args.append((tk, db, phase))

print("args for Gmin parallelisation: ",
      Gmin_args[:5])
print(Gmin_args[-5:])
print("args length: ", len(Gmin_args))

with Pool() as pool:
    # Gmin_results = pool.starmap(tc_calculation_Gmin, Gmin_args)
    DGM_results = pool.starmap(tc_calculation_NormDrivingForce, Gmin_args)

elapsed_time = time.time() - start_time
print("Time taken: ", int(elapsed_time), "seconds")

# %%
# check again how many processes:
print("number of processes: ", len(DGM_results))

# in each process: list_of_conditions+'gm(phase)'
print("how many data categories in each process: ",  len(DGM_results[0]))

# the data length inside the above outputs categories
print("data length inside: ", len(DGM_results[0][1]))
# Out:
# number of processes:  650
# how many data categories in each process:  2
# data length inside:  250

# %% [markdown]
# ### Unpack the calculation results

# %% [markdown]
# #### Analyse FullEquil results

# %%
# Merge results from different processes
list_of_conditions = [res[0] for res in FullEquil_results]
list_np_HEMATITE = [res[1] for res in FullEquil_results]
list_np_MAGNETITE = [res[2] for res in FullEquil_results]
list_np_WUSTITE = [res[3] for res in FullEquil_results]
list_np_BCC_A2 = [res[4] for res in FullEquil_results]
list_np_LIQUID = [res[5] for res in FullEquil_results]

# print(len(list_of_conditions))

# Flattening the lists
list_of_conditions = [
    item for sublist in list_of_conditions for item in sublist]
list_np_HEMATITE = [item for sublist in list_np_HEMATITE for item in sublist]
list_np_MAGNETITE = [item for sublist in list_np_MAGNETITE for item in sublist]
list_np_WUSTITE = [item for sublist in list_np_WUSTITE for item in sublist]
list_np_BCC_A2 = [item for sublist in list_np_BCC_A2 for item in sublist]
list_np_LIQUID = [item for sublist in list_np_LIQUID for item in sublist]

# print(len(list_of_conditions))

# list_np_FCC_L12_merge = [max(a, b, c) for a, b, c in zip(
#     list_np_FCC_L12, list_np_FCC_L12_1, list_np_FCC_L12_2)]

df_FullEquil = pd.DataFrame(columns=['lnacr_o', 'T', 'np(HEMATITE)',
                                     'np(MAGNETITE)', 'np(WUSTITE)', 'np(BCC_A2)', 'np(LIQUID)'])

# Convert conditions and results to DataFrame
df_FullEquil = pd.DataFrame({
    'lnacr_o': [dict(conditions)['lnacr(o)'] for conditions in list_of_conditions],
    'T': [dict(conditions)['T'] for conditions in list_of_conditions],
    'np(HEMATITE)': list_np_HEMATITE,
    'np(MAGNETITE)': list_np_MAGNETITE,
    'np(WUSTITE)': list_np_WUSTITE,
    'np(BCC_A2)': list_np_BCC_A2,
    'np(LIQUID)': list_np_LIQUID
})

df_FullEquil.to_excel(os.path.join(current_directory,
                                   "tc_df_FullEquil_check.xlsx"), index=False)

display(df_FullEquil.head(3), df_FullEquil.shape)
# Out:
#      lnacr_o       T  np(HEMATITE)  np(MAGNETITE)  np(WUSTITE)  np(BCC_A2)  \
# 0 -80.000000  373.15           0.0            0.0          0.0         1.0
# 1 -79.698795  373.15           0.0            0.0          0.0         1.0
# 2 -79.397590  373.15           0.0            0.0          0.0         1.0
#
#    np(LIQUID)
# 0         0.0
# 1         0.0
# 2         0.0
# (32500, 7)

# %% [markdown]
# #### Analyse Gmin results

# %%
from copy import deepcopy


def process_data(Gmin_args, Gmin_results):

    Gmin_gm_values = {}
    Gmin_phase_conditions = {}

    for args, result in zip(Gmin_args, Gmin_results):
        tk, db, phase = deepcopy(args)
        conditions, gm_values = deepcopy(result)

        lnacr_o_values = [dict(cond)['lnacr(o)'] for cond in conditions]
        T_values = [dict(cond)['T'] for cond in conditions]

        if phase in Gmin_gm_values:
            Gmin_gm_values[phase].extend(gm_values)
        else:
            Gmin_gm_values[phase] = gm_values

        if phase in Gmin_phase_conditions:
            Gmin_phase_conditions[phase]['lnacr(o)'].extend(lnacr_o_values)
            Gmin_phase_conditions[phase]['T'].extend(T_values)
        else:
            Gmin_phase_conditions[phase] = {
                'lnacr(o)': lnacr_o_values, 'T': T_values}

    return Gmin_gm_values, Gmin_phase_conditions


Gmin_phase_list = [phase for db_phases in databases_phases.values()
                   for phase in db_phases]
print(Gmin_phase_list)

print("Length of Gmin_args:", len(Gmin_args))
print("Length of Gmin_results:", len(Gmin_results))

Gmin_gm_values, Gmin_phase_conditions = process_data(
    Gmin_args, Gmin_results)

print("temperature_grid x acc_grid:", 130*250)
print("length of Gmin_gm_values: ", len(Gmin_gm_values['BCC_A2']))

for i, phase in enumerate(Gmin_phase_list):
    assert Gmin_phase_conditions[Gmin_phase_list[0]
                                 ] == Gmin_phase_conditions[phase]

Gmin_conditions = Gmin_phase_conditions[Gmin_phase_list[0]]
print("length of Gmin_conditions: ", len(Gmin_conditions['lnacr(o)']))
# Out:
# ['HEMATITE', 'MAGNETITE', 'WUSTITE', 'BCC_A2', 'LIQUID']
# Length of Gmin_args: 650
# Length of Gmin_results: 650
# temperature_grid x acc_grid: 32500
# length of Gmin_gm_values:  32500
# length of Gmin_conditions:  32500

# %%
df_Gmin = pd.DataFrame({
    'lnacr_o':  Gmin_conditions['lnacr(o)'],
    'T': Gmin_conditions['T'],
    **{f'gm({phase})': Gmin_gm_values.get(phase, []) for phase in Gmin_phase_list}
})

df_Gmin.to_excel(os.path.join(current_directory,
                 "tc_df_Gmin_check.xlsx"), index=False)

display(df_Gmin.head(3), df_Gmin.shape)
# Out:
#      lnacr_o       T   gm(HEMATITE)  gm(MAGNETITE)    gm(WUSTITE)  \
# 0 -80.000000  373.15 -171712.607935 -168062.495242 -147721.538762
# 1 -79.698795  373.15 -171712.607935 -168062.495242 -147721.538762
# 2 -79.397590  373.15 -171712.607935 -168062.495242 -147721.538762
#
#      gm(BCC_A2)   gm(LIQUID)
# 0 -10401.978922  4768.876357
# 1 -10401.978922  4768.876357
# 2 -10401.978922  4768.876357
# (32500, 7)

# %% [markdown]
# #### Analyse NormDrivingForce results

# %%
from copy import deepcopy


def process_data(DGM_args, DGM_results):

    DGM_gm_values = {}
    DGM_phase_conditions = {}

    for args, result in zip(DGM_args, DGM_results):
        tk, db, phase = deepcopy(args)
        conditions, gm_values = deepcopy(result)

        lnacr_o_values = [dict(cond)['lnacr(o)'] for cond in conditions]
        T_values = [dict(cond)['T'] for cond in conditions]

        if phase in DGM_gm_values:
            DGM_gm_values[phase].extend(gm_values)
        else:
            DGM_gm_values[phase] = gm_values

        if phase in DGM_phase_conditions:
            DGM_phase_conditions[phase]['lnacr(o)'].extend(lnacr_o_values)
            DGM_phase_conditions[phase]['T'].extend(T_values)
        else:
            DGM_phase_conditions[phase] = {
                'lnacr(o)': lnacr_o_values, 'T': T_values}

    return DGM_gm_values, DGM_phase_conditions


DGM_phase_list = [phase for db_phases in databases_phases.values()
                  for phase in db_phases]
print(DGM_phase_list)

print("Length of DGM_args:", len(Gmin_args))
print("Length of DGM_results:", len(DGM_results))

DGM_gm_values, DGM_phase_conditions = process_data(
    Gmin_args, DGM_results)

print("temperature_grid x acc_grid:", 130*250)
print("length of DGM_gm_values: ", len(DGM_gm_values['BCC_A2']))

for i, phase in enumerate(DGM_phase_list):
    assert DGM_phase_conditions[DGM_phase_list[0]
                                ] == DGM_phase_conditions[phase]

DGM_conditions = DGM_phase_conditions[DGM_phase_list[0]]
print("length of DGM_conditions: ", len(DGM_conditions['lnacr(o)']))
# Out:
# ['HEMATITE', 'MAGNETITE', 'WUSTITE', 'BCC_A2', 'LIQUID']
# Length of DGM_args: 650
# Length of DGM_results: 650
# temperature_grid x acc_grid: 32500
# length of DGM_gm_values:  32500
# length of DGM_conditions:  32500

# %%
df_DGM = pd.DataFrame({
    'lnacr_o':  DGM_conditions['lnacr(o)'],
    'T': DGM_conditions['T'],
    **{f'gm({phase})': DGM_gm_values.get(phase, []) for phase in DGM_phase_list}
})

df_DGM.to_excel(os.path.join(current_directory,
                             "tc_df_DGM_check.xlsx"), index=False)

display(df_DGM.head(3), df_Gmin.shape)
# Out:
#      lnacr_o       T  gm(HEMATITE)  gm(MAGNETITE)  gm(WUSTITE)  gm(BCC_A2)  \
# 0 -80.000000  373.15     26.252729      29.678401    32.435259   70.905254
# 1 -79.698795  373.15     26.433452      29.850518    32.589961   70.905254
# 2 -79.397590  373.15     26.614175      30.022635    32.744663   70.905254
#
#    gm(LIQUID)
# 0   66.015467
# 1   66.015467
# 2   66.015467
# (32500, 7)

# %% [markdown]
# ### FullEquil: steping at one temperature

# %%
# Filter the dataframe for rows where T is 373.15
filtered_df_FullEquil = df_FullEquil[df_FullEquil['T'] == 473.15]
filtered_df_FullEquil.to_excel(os.path.join(current_directory,
                                            "tc_df_FullEquil_check_filter.xlsx"), index=False)

plt.figure(figsize=(5, 5))
colors = {
    'HEMATITE': '#006D2C',  # A forest green
    'MAGNETITE': '#08519C',  # A navy blue
    'WUSTITE': '#54278F',  # A dark purple
    'BCC_A2': '#EC7014',  # A burnt orange
    'LIQUID': '#A50F15'  # A deep red
}

plt.plot(filtered_df_FullEquil['lnacr_o'], filtered_df_FullEquil['np(HEMATITE)'],
         color=colors['HEMATITE'], label='HEMATITE')
plt.plot(filtered_df_FullEquil['lnacr_o'], filtered_df_FullEquil['np(MAGNETITE)'],
         color=colors['MAGNETITE'], label='MAGNETITE')
# plt.plot(filtered_df_FullEquil['lnacr_o'], filtered_df_FullEquil['np(WUSTITE)'],
#          color=colors['WUSTITE'], label='WUSTITE')
plt.plot(filtered_df_FullEquil['lnacr_o'], filtered_df_FullEquil['np(BCC_A2)'],
         color=colors['BCC_A2'], label='BCC_A2')
# plt.plot(filtered_df_FullEquil['lnacr_o'], filtered_df_FullEquil['np(LIQUID)'],
#          color=colors['LIQUID'], label='LIQUID')

plt.xlabel('LN O activtity')
plt.ylabel('Mole fraction')
plt.grid(True)
plt.legend()
# plt.xlim(-100, -25)
plt.show()

# %% [markdown]
# ### FullEquil: mapping for one phase

# %%
plt.figure(figsize=(5, 5))
plt.scatter(df_FullEquil['lnacr_o'], df_FullEquil['T'],
            c=df_FullEquil['np(HEMATITE)'], s=5,  alpha=0.6)
plt.xlabel(df_FullEquil.columns[0])
plt.ylabel(df_FullEquil.columns[1])
plt.grid(True)
# plt.legend()
plt.show()

# %% [markdown]
# ### FullEquil: Mapping for all phases

# %%
# Splitting the main dataframe into individual dataframes and filtering them
df_FullEquil_HEMATITE = df_FullEquil[['lnacr_o', 'T', 'np(HEMATITE)']]
df_FullEquil_HEMATITE = df_FullEquil_HEMATITE[
    df_FullEquil_HEMATITE['np(HEMATITE)'] >= 0.001]

df_FullEquil_MAGNETITE = df_FullEquil[['lnacr_o', 'T', 'np(MAGNETITE)']]
df_FullEquil_MAGNETITE = df_FullEquil_MAGNETITE[
    df_FullEquil_MAGNETITE['np(MAGNETITE)'] >= 0.001]

df_FullEquil_WUSTITE = df_FullEquil[['lnacr_o', 'T', 'np(WUSTITE)']]
df_FullEquil_WUSTITE = df_FullEquil_WUSTITE[df_FullEquil_WUSTITE['np(WUSTITE)']
                                            >= 0.001]

df_FullEquil_BCC_A2 = df_FullEquil[['lnacr_o', 'T', 'np(BCC_A2)']]
df_FullEquil_BCC_A2 = df_FullEquil_BCC_A2[df_FullEquil_BCC_A2['np(BCC_A2)']
                                          >= 0.001]

df_FullEquil_LIQUID = df_FullEquil[['lnacr_o', 'T', 'np(LIQUID)']]
df_FullEquil_LIQUID = df_FullEquil_LIQUID[df_FullEquil_LIQUID['np(LIQUID)']
                                          >= 0.001]

# %%
# Plotting the individual dataframes
plt.figure(figsize=(5, 5))

plt.scatter(df_FullEquil_HEMATITE['lnacr_o'], df_FullEquil_HEMATITE['T'], s=10,
            label='HEMATITE', color=colors['HEMATITE'], alpha=0.5)

plt.scatter(df_FullEquil_MAGNETITE['lnacr_o'], df_FullEquil_MAGNETITE['T'], s=10,
            label='MAGNETITE', color=colors['MAGNETITE'], alpha=0.5)

plt.scatter(df_FullEquil_WUSTITE['lnacr_o'], df_FullEquil_WUSTITE['T'], s=10,
            label='WUSTITE', color=colors['WUSTITE'], alpha=0.5)

plt.scatter(df_FullEquil_BCC_A2['lnacr_o'], df_FullEquil_BCC_A2['T'], s=10,
            label='BCC_A2', color=colors['BCC_A2'], alpha=0.5)

plt.scatter(df_FullEquil_LIQUID['lnacr_o'], df_FullEquil_LIQUID['T'], s=10,
            label='LIQUID', color=colors['LIQUID'], alpha=0.5)

plt.xlabel('LN O activtity', fontsize=14)
plt.ylabel('T (K)', fontsize=14)
plt.title('full equilibrium', fontsize=14)
plt.legend(fontsize=12, loc='upper left',
           facecolor='white', edgecolor='black', framealpha=1)
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.xlim([min(df_Gmin['lnacr_o']), max(df_Gmin['lnacr_o'])])
plt.ylim([min(df_Gmin['T']), max(df_Gmin['T'])])
plt.tight_layout()

plt_output_fname = "Oxide_TC_FullEquil.png"
plt.savefig(os.path.join(current_directory, plt_output_fname),
            format='png', dpi=300, bbox_inches='tight', )

plt.show()

# %% [markdown]
# ### Gmin: mapping for individual phase

# %%
display(df_Gmin.head(3), df_Gmin.shape)
# Out:
#      lnacr_o       T   gm(HEMATITE)  gm(MAGNETITE)    gm(WUSTITE)  \
# 0 -80.000000  373.15 -171712.607935 -168062.495242 -147721.538762
# 1 -79.698795  373.15 -171712.607935 -168062.495242 -147721.538762
# 2 -79.397590  373.15 -171712.607935 -168062.495242 -147721.538762
#
#      gm(BCC_A2)   gm(LIQUID)
# 0 -10401.978922  4768.876357
# 1 -10401.978922  4768.876357
# 2 -10401.978922  4768.876357
# (32500, 7)

# %%
from matplotlib.ticker import ScalarFormatter

# Define the colormaps for each phase
colormaps = {
    'HEMATITE': 'Greens',
    'MAGNETITE': 'Blues',
    'WUSTITE': 'Purples',
    'BCC_A2': 'YlOrBr',
    'LIQUID': 'RdPu'
}

# Create a new figure with subplots
fig, axs = plt.subplots(nrows=1, ncols=len(
    Gmin_phase_list), figsize=(3.4 * len(Gmin_phase_list), 3), sharex=True, sharey=True)

for i, phase in enumerate(Gmin_phase_list):

    sc = axs[i].scatter(df_Gmin['lnacr_o'], df_Gmin['T'],
                        c=df_Gmin[f'gm({phase})'], cmap=colormaps[phase], s=5, alpha=0.6)

    cbar = plt.colorbar(sc, ax=axs[i])

    # Change colorbar numbering to scientific notation
    formatter = ScalarFormatter(useMathText=True)
    formatter.set_scientific(True)
    formatter.set_powerlimits((-1, 1))
    cbar.ax.yaxis.set_major_formatter(formatter)

    # Label the colorbar of the last plot only
    if i == len(Gmin_phase_list) - 1:
        cbar.set_label('molar Gibbs energy (J/mol)', fontsize=14)

    axs[i].set_xlabel('LN O activity', fontsize=14)
    axs[i].set_ylabel('T (K)', fontsize=14)
    axs[i].set_xlim([min(df_Gmin['lnacr_o']), max(df_Gmin['lnacr_o'])])
    axs[i].set_ylim([min(df_Gmin['T']), max(df_Gmin['T'])])
    axs[i].grid(True, which='both', linestyle='--', linewidth=0.5)
    axs[i].set_title(f'{phase}')
    # axs[i].set_aspect('equal', 'box')

fig.tight_layout()
fig.savefig('Oxide_TC_Gm_phases.png',
            format='png', dpi=300, bbox_inches='tight')

plt.show()

# %% [markdown]
# ### Gmin: Mapping for all phases

# %%
columns_to_compare = [f'gm({phase})' for phase in Gmin_phase_list]
df_Gmin_HEMATITE = df_Gmin[df_Gmin['gm(HEMATITE)']
                           == df_Gmin[columns_to_compare].min(axis=1)]

df_Gmin_MAGNETITE = df_Gmin[df_Gmin['gm(MAGNETITE)']
                            == df_Gmin[columns_to_compare].min(axis=1)]
df_Gmin_WUSTITE = df_Gmin[df_Gmin['gm(WUSTITE)']
                          == df_Gmin[columns_to_compare].min(axis=1)]
df_Gmin_BCC_A2 = df_Gmin[df_Gmin['gm(BCC_A2)']
                         == df_Gmin[columns_to_compare].min(axis=1)]
df_Gmin_LIQUID = df_Gmin[df_Gmin['gm(LIQUID)']
                         == df_Gmin[columns_to_compare].min(axis=1)]

# Plotting the individual dataframes
plt.figure(figsize=(5, 5))

plt.scatter(df_Gmin_HEMATITE['lnacr_o'], df_Gmin_HEMATITE['T'], s=10,
            label='HEMATITE', color=colors['HEMATITE'], alpha=0.5)

plt.scatter(df_Gmin_MAGNETITE['lnacr_o'], df_Gmin_MAGNETITE['T'], s=10,
            label='MAGNETITE', color=colors['MAGNETITE'], alpha=0.5)

plt.scatter(df_Gmin_WUSTITE['lnacr_o'], df_Gmin_WUSTITE['T'], s=10,
            label='WUSTITE', color=colors['WUSTITE'], alpha=0.5)

plt.scatter(df_Gmin_BCC_A2['lnacr_o'], df_Gmin_BCC_A2['T'], s=10,
            label='BCC_A2', color=colors['BCC_A2'], alpha=0.5)

plt.scatter(df_Gmin_LIQUID['lnacr_o'], df_Gmin_LIQUID['T'], s=10,
            label='LIQUID', color=colors['LIQUID'], alpha=0.5)

plt.xlabel('LN O activtity', fontsize=14)
plt.ylabel('T (K)', fontsize=14)
plt.title('minimum Gibbs energy', fontsize=14)
plt.legend(fontsize=12, loc='upper left',
           facecolor='white', edgecolor='black', framealpha=1)
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.xlim([min(df_Gmin['lnacr_o']), max(df_Gmin['lnacr_o'])])
plt.ylim([min(df_Gmin['T']), max(df_Gmin['T'])])
plt.tight_layout()

plt_output_fname = "Oxide_TC_Gmin.png"
plt.savefig(os.path.join(current_directory, plt_output_fname),
            format='png', dpi=300, bbox_inches='tight')

plt.show()

# %% [markdown]
# ### NormDrivingForce: Mapping for individual phase

# %%
from matplotlib.ticker import ScalarFormatter

# Define the colormaps for each phase
colormaps = {
    'HEMATITE': 'Greens',
    'MAGNETITE': 'Blues',
    'WUSTITE': 'Purples',
    'BCC_A2': 'YlOrBr',
    'LIQUID': 'RdPu'
}

# Create a new figure with subplots
fig, axs = plt.subplots(nrows=1, ncols=len(
    DGM_phase_list), figsize=(3.4 * len(DGM_phase_list), 3), sharex=True, sharey=True)

for i, phase in enumerate(DGM_phase_list):

    sc = axs[i].scatter(df_DGM['lnacr_o'], df_DGM['T'],
                        c=df_DGM[f'gm({phase})'], cmap=colormaps[phase], s=5, alpha=0.6)

    cbar = plt.colorbar(sc, ax=axs[i])

    # Change colorbar numbering to scientific notation
    formatter = ScalarFormatter(useMathText=True)
    formatter.set_scientific(True)
    formatter.set_powerlimits((-1, 1))
    cbar.ax.yaxis.set_major_formatter(formatter)

    # Label the colorbar of the last plot only
    if i == len(DGM_phase_list) - 1:
        cbar.set_label('Driving force normalised by RT', fontsize=14)

    axs[i].set_xlabel('LN O activity', fontsize=14)
    axs[i].set_ylabel('T (K)', fontsize=14)
    axs[i].set_xlim([min(df_DGM['lnacr_o']), max(df_DGM['lnacr_o'])])
    axs[i].set_ylim([min(df_DGM['T']), max(df_DGM['T'])])
    axs[i].grid(True, which='both', linestyle='--', linewidth=0.5)
    axs[i].set_title(f'{phase}')
    # axs[i].set_aspect('equal', 'box')

fig.tight_layout()
fig.savefig('Oxide_TC_dgm_phases.png',
            format='png', dpi=300, bbox_inches='tight')

plt.show()

# %% [markdown]
# ### DGM: Mapping for all phases

# %%
columns_to_compare = [f'gm({phase})' for phase in DGM_phase_list]
# columns_to_compare = ['gm(HEMATITE)', 'gm(MAGNETITE)', 'gm(WUSTITE)', 'gm(LIQUID)' ]

df_DGM_HEMATITE = df_DGM[df_DGM['gm(HEMATITE)']
                         == df_DGM[columns_to_compare].max(axis=1)]
df_DGM_MAGNETITE = df_DGM[df_DGM['gm(MAGNETITE)']
                          == df_DGM[columns_to_compare].max(axis=1)]
df_DGM_WUSTITE = df_DGM[df_DGM['gm(WUSTITE)']
                        == df_DGM[columns_to_compare].max(axis=1)]
df_DGM_BCC_A2 = df_DGM[df_DGM['gm(BCC_A2)']
                       == df_DGM[columns_to_compare].max(axis=1)]
df_DGM_LIQUID = df_DGM[df_DGM['gm(LIQUID)']
                       == df_DGM[columns_to_compare].max(axis=1)]

# Plotting the individual dataframes
plt.figure(figsize=(5, 5))

plt.scatter(df_DGM_HEMATITE['lnacr_o'], df_DGM_HEMATITE['T'], s=10,
            label='HEMATITE', color=colors['HEMATITE'], alpha=0.5)

plt.scatter(df_DGM_MAGNETITE['lnacr_o'], df_DGM_MAGNETITE['T'], s=10,
            label='MAGNETITE', color=colors['MAGNETITE'], alpha=0.5)

plt.scatter(df_DGM_WUSTITE['lnacr_o'], df_DGM_WUSTITE['T'], s=10,
            label='WUSTITE', color=colors['WUSTITE'], alpha=0.5)

plt.scatter(df_DGM_BCC_A2['lnacr_o'], df_DGM_BCC_A2['T'], s=10,
            label='BCC_A2', color=colors['BCC_A2'], alpha=0.5)

plt.scatter(df_DGM_LIQUID['lnacr_o'], df_DGM_LIQUID['T'], s=10,
            label='LIQUID', color=colors['LIQUID'], alpha=0.5)

plt.xlabel('LN O activtity', fontsize=14)
plt.ylabel('T (K)', fontsize=14)
plt.title('minimum Gibbs energy', fontsize=14)
plt.legend(fontsize=12, loc='upper left',
           facecolor='white', edgecolor='black', framealpha=1)
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.xlim([min(df_DGM['lnacr_o']), max(df_DGM['lnacr_o'])])
plt.ylim([min(df_DGM['T']), max(df_DGM['T'])])
plt.tight_layout()

plt_output_fname = "Oxide_TC_DGMmax.png"
plt.savefig(os.path.join(current_directory, plt_output_fname),
            format='png', dpi=300, bbox_inches='tight')
plt.show()
