# %%
# # Development mode: automatic reloading of modules
# %load_ext autoreload
# %autoreload 2

# %%
import pickle
from tc_python import *
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from multiprocessing import Pool
import os
from itertools import product
import time
import matplotlib
matplotlib.rcParams['font.family'] = 'FreeSans'

num_cpus = os.cpu_count()
print(f'cpu_count: {num_cpus}')
# Out:
# cpu_count: 72

# %%
basename = 'IronOxide_TC_calculations_TCFE_TCOX'

current_directory = os.getcwd()
cache_fname = basename + '.ipynb' + "_cache"
output_fname = os.path.splitext(basename)[0]

print("Cache Filename: ", cache_fname)
print("Output Filename: ", output_fname)
print("Current Dir: ", current_directory)
# Out:
# Cache Filename:  IronOxide_TC_calculations_TCFE_TCOX.ipynb_cache
# Output Filename:  IronOxide_TC_calculations_TCFE_TCOX
# Current Dir:  /nethome/home3/yuxiang.wu/IronOxide_TC

# %% [markdown]
# ### TC functions
#
# #### `tc_calculation_FullEquil`: compute the equilibrium phase fraction as (acr, T)

# %%
def tc_calculation_FullEquil(tk):
    with TCPython() as start:
        batch_calculation = (
            start
            .set_cache_folder(os.path.join(current_directory, cache_fname))
            .set_ges_version(5)
            .select_database_and_elements("tcfe13", ["Fe", "O"])
            .deselect_phase("*")
            .select_phase("BCC_A2 LIQUID")
            .select_database_and_elements("tcox10", ["Fe", "O"])
            .deselect_phase("*")
            .select_phase("CORUNDUM SPINEL HALITE")
            .select_database_and_elements("ssub5", ["Fe", "O"])
            .deselect_phase("*")
            .select_phase("GAS")
            .get_system()
            .with_batch_equilibrium_calculation()
            .set_condition("T", 100+273.15)
            .set_condition("P", 0.5)
            .set_condition("lnacr(o)", -400)
            .with_reference_state("O", 'GAS', tk, 10000)
            .disable_global_minimization()
        )

        # Generate condition combinations for equilibrium calculations
        k = 150
        list_of_conditions = [(("lnacr(o)", lnacr_o), ("T", tk))
                              for lnacr_o in np.linspace(-60, -5, k)]

        batch_calculation.set_conditions_for_equilibria(list_of_conditions)

        results = batch_calculation.calculate(
            ["np(CORUNDUM)", "np(SPINEL)", "np(HALITE)", "np(BCC_A2)", "np(LIQUID)"], 100)

        return (
            list_of_conditions,
            results.get_values_of('np(CORUNDUM)'),
            results.get_values_of('np(SPINEL)'),
            results.get_values_of('np(HALITE)'),
            results.get_values_of('np(BCC_A2)'),
            results.get_values_of('np(LIQUID)')
        )

# %% [markdown]
# #### `tc_calculation_Gmin`: compute the Gibbs energy as (database, phase, acr, T)

# %%
def tc_calculation_Gmin(tk, db, phase):
    with TCPython() as start:
        batch_calculation = (
            start
            .set_cache_folder(os.path.join(current_directory, cache_fname))
            .set_ges_version(5))

        batch_calculation = (
            batch_calculation
            .select_database_and_elements(db, ["Fe", "O"])
            .deselect_phase("*")
            .select_phase(f"{phase}")
            .select_database_and_elements("ssub5", ["Fe", "O"])
            .deselect_phase("*")
            .select_phase("GAS")
        )

        # Continue with the rest of the method chain
        batch_calculation = (
            batch_calculation
            .get_system()
            .with_batch_equilibrium_calculation()
            .set_condition("T", 100+273.15)
            .set_condition("P", 0.5)
            .set_condition("lnacr(o)", -400)
            .with_reference_state("O", 'GAS', tk, 10000)
            .disable_global_minimization()
        )

        # Generate condition combinations for equilibrium calculations
        k = 150
        list_of_conditions = [(("lnacr(o)", lnacr_o), ("T", tk))
                              for lnacr_o in np.linspace(-60, -5, k)]

        batch_calculation.set_conditions_for_equilibria(list_of_conditions)

        # run a calculation first
        results = batch_calculation.calculate([f"gm({phase})"], 100)

        # # turn "GAS" into Dormant and run the same calculation again
        # batch_calculation.set_phase_to_dormant("GAS")
        # results = batch_calculation.calculate([f"gm({phase})"], 100)

        return (
            list_of_conditions,
            results.get_values_of(f"gm({phase})")
        )

# %% [markdown]
# #### `tc_calculation_NormDrivingForce`: compute the Normalised Driving Force as (database, phase, acr, T)

# %%
def tc_calculation_NormDrivingForce(tk, db, phase):
    with TCPython() as start:
        batch_calculation = (
            start
            .set_cache_folder(os.path.join(current_directory, cache_fname))
            .set_ges_version(5))

        batch_calculation = (
            batch_calculation
            .select_database_and_elements(db, ["Fe", "O"])
            .deselect_phase("*")
            .select_phase(f"{phase}")
            .select_database_and_elements('ssub5', ["Fe", "O"])
            .deselect_phase("*")
            .select_phase("GAS")
        )

        # Continue with the rest of the method chain
        batch_calculation = (
            batch_calculation
            .get_system()
            .with_batch_equilibrium_calculation()
            .set_condition("T", 100+273.15)
            .set_condition("P", 0.5)
            .set_condition("lnacr(o)", -400)
            .set_phase_to_dormant(phase)
            .with_reference_state("O", 'GAS', tk, 10000)
            .disable_global_minimization()
        )

        # Generate condition combinations for equilibrium calculations
        k = 150
        list_of_conditions = [(("lnacr(o)", lnacr_o), ("T", tk))
                              for lnacr_o in np.linspace(-60, -5, k)]

        batch_calculation.set_conditions_for_equilibria(list_of_conditions)

        # run a calculation first
        results = batch_calculation.calculate([f"dgm({phase})"], 100)

        return (
            list_of_conditions,
            results.get_values_of(f"dgm({phase})")
        )

# %% [markdown]
# ### Parallelising TC calculation

# %%
start_time = time.time()

# paralleising FullEquil
tk_values = np.arange(0+273.15, 605+273.15, 5)
print("temperature range first and last 5 values: ",
      tk_values[:5], tk_values[-5:])
print("FullEquil processes: ", len(tk_values))

# parallelising Gmin and DGM
databases_phases = {
    "tcox10": ["CORUNDUM", "SPINEL", "HALITE"],
    "tcfe13": ["BCC_A2", "LIQUID"]
}

Gmin_DGM_args = []
for tk in tk_values:
    for db, phases in databases_phases.items():
        for phase in phases:
            Gmin_DGM_args.append((tk, db, phase))

print("args for Gmin/DGM parallelisation: ",
      Gmin_DGM_args[:5])
print("Gmin/DGM processes: ", len(Gmin_DGM_args))

# %%%%% load data or run calculations %%%%%
try:
    with open(basename + "_FullEquil_results.pkl", "rb") as f:
        FullEquil_results = pickle.load(f)
    with open(basename + "_Gmin_results.pkl", "rb") as f:
        Gmin_results = pickle.load(f)
    with open(basename + "_DGM_results.pkl", "rb") as f:
        DGM_results = pickle.load(f)
    print("Loaded saved results.")
except FileNotFoundError:
    print("Saved results not found. Running calculations.")

    # run the large calculation
    with Pool(processes=num_cpus-1) as pool:
        FullEquil_results = pool.map(tc_calculation_FullEquil, tk_values)
        Gmin_results = pool.starmap(tc_calculation_Gmin, Gmin_DGM_args)
        DGM_results = pool.starmap(
            tc_calculation_NormDrivingForce, Gmin_DGM_args)

    # Save the results
    with open(basename + "_FullEquil_results.pkl", "wb") as f:
        pickle.dump(FullEquil_results, f)
    with open(basename + "_Gmin_results.pkl", "wb") as f:
        pickle.dump(Gmin_results, f)
    with open(basename + "_DGM_results.pkl", "wb") as f:
        pickle.dump(DGM_results, f)

# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

elapsed_time = time.time() - start_time
print("Time taken: ", int(elapsed_time), "seconds")
# Out:
# temperature range first and last 5 values:  [273.15 278.15 283.15 288.15 293.15] [853.15 858.15 863.15 868.15 873.15]
# FullEquil processes:  121
# args for Gmin/DGM parallelisation:  [(273.15, 'tcox10', 'CORUNDUM'), (273.15, 'tcox10', 'SPINEL'), (273.15, 'tcox10', 'HALITE'), (273.15, 'tcfe13', 'BCC_A2'), (273.15, 'tcfe13', 'LIQUID')]
# Gmin/DGM processes:  605
# Saved results not found. Running calculations.
# 17:59:31,532 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:31,550 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:31,663 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:31,669 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:31,645 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:31,707 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:31,729 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:31,732 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:31,770 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:31,787 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:31,828 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:31,868 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:31,887 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:31,894 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:31,894 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:31,807 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:31,907 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:31,948 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:31,965 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:31,994 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,007 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,018 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,060 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,171 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,249 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,221 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,221 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,248 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,273 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,301 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,297 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,293 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,373 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,434 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,469 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,505 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,510 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,517 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,530 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,580 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,593 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,588 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,615 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,640 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,665 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,672 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,678 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,688 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,717 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,691 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,710 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,735 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,731 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,774 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,784 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,786 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,831 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,841 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,850 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,871 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,889 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,879 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,917 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,926 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,950 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,951 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:32,968 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:33,081 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:33,087 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:33,118 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:33,223 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 17:59:35,956 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:36,072 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:36,167 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:36,172 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:36,223 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:36,243 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:36,272 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:36,357 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:36,399 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:36,370 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:36,423 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:36,440 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:36,452 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:36,475 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:36,609 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:36,715 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:36,708 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:36,887 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:37,101 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:37,153 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:37,276 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:37,352 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:37,369 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:37,407 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:37,442 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:37,453 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:37,491 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:37,726 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:37,713 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:37,773 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:37,883 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:37,940 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:37,943 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:37,938 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:38,009 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:38,011 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:38,061 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:38,109 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:38,129 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:38,212 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:38,225 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:38,254 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:38,299 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:38,341 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:38,343 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:38,354 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:38,352 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:38,372 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:38,372 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:38,386 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:38,438 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:38,471 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:38,464 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:38,501 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:38,522 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:38,515 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:38,538 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:38,518 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:38,547 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:38,570 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:38,647 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:38,632 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:38,648 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:38,696 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:38,717 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:38,746 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:38,779 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:38,832 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:38,965 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:39,027 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 17:59:39,145 [Thread-1] INFO  CalculationEngine: Opening database::tcfe13::
#
# 18:00:02,479 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 18:00:02,483 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 18:00:02,484 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 18:00:02,485 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 18:00:02,485 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 18:00:02,485 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 18:00:02,485 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 18:00:02,486 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 18:00:02,486 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 18:00:02,486 [Thread-1] INFO  CalculationEngine:    'M J Assael, J Phys Chem Ref Data 35 (2006) 285; Fe, Al'
#
# 18:00:02,486 [Thread-1] INFO  CalculationEngine:    'R Zhang, Thermo-Calc Software AB: assessing the viscosity of molten
#
# 18:00:02,487 [Thread-1] INFO  CalculationEngine:        oxides, 2019'
#
# 18:00:02,487 [Thread-1] INFO  CalculationEngine:    'Same or similar interaction as in the corresponding stable phase'
#
# 18:00:02,487 [Thread-1] INFO  CalculationEngine:    'C.-M. Arvhult, Optimized ELRS
#
# 18:00:02,487 [Thread-1] INFO  CalculationEngine:         THCD, Thermo-Calc Software. '
#
# 18:00:02,487 [Thread-1] INFO  CalculationEngine:    'H-L Chen, in TCAL7.0, Evaluation and modeling of electrical resistivity
#
# 18:00:02,487 [Thread-1] INFO  CalculationEngine:         thermal conductivity'
#
# 18:00:02,488 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software, 2020: ELRS/THCD of liquid'
#
# 18:00:02,488 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB (2020): assessing the surface tension
#
# 18:00:02,488 [Thread-1] INFO  CalculationEngine:        of metallic liquid'
#
# 18:00:02,488 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden 2023; Reassessment of surface
#
# 18:00:02,488 [Thread-1] INFO  CalculationEngine:        tension using RK rule'
#
# 18:00:02,489 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Surface tensions for oxide liquid in TCOX, Thermo-Calc Software
#
# 18:00:02,489 [Thread-1] INFO  CalculationEngine:        AB, Sweden, 2020-2022'
#
# 18:00:02,968 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 18:00:02,980 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 18:00:02,969 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 18:00:02,981 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 18:00:02,970 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 18:00:02,982 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 18:00:02,970 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 18:00:02,983 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 18:00:02,983 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 18:00:02,970 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 18:00:02,970 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 18:00:02,983 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 18:00:02,970 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 18:00:03,097 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 18:00:02,983 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 18:00:02,970 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 18:00:03,101 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 18:00:02,983 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 18:00:02,971 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 18:00:02,983 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 18:00:03,101 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 18:00:02,971 [Thread-1] INFO  CalculationEngine:    'M J Assael, J Phys Chem Ref Data 35 (2006) 285; Fe, Al'
#
# 18:00:02,984 [Thread-1] INFO  CalculationEngine:    'M J Assael, J Phys Chem Ref Data 35 (2006) 285; Fe, Al'
#
# 18:00:03,102 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 18:00:02,971 [Thread-1] INFO  CalculationEngine:    'R Zhang, Thermo-Calc Software AB: assessing the viscosity of molten
#
# 18:00:03,102 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 18:00:03,187 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 18:00:02,984 [Thread-1] INFO  CalculationEngine:    'R Zhang, Thermo-Calc Software AB: assessing the viscosity of molten
#
# 18:00:03,102 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 18:00:03,191 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 18:00:02,971 [Thread-1] INFO  CalculationEngine:        oxides, 2019'
#
# 18:00:02,984 [Thread-1] INFO  CalculationEngine:        oxides, 2019'
#
# 18:00:02,984 [Thread-1] INFO  CalculationEngine:    'Same or similar interaction as in the corresponding stable phase'
#
# 18:00:03,102 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 18:00:03,192 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 18:00:03,102 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 18:00:02,971 [Thread-1] INFO  CalculationEngine:    'Same or similar interaction as in the corresponding stable phase'
#
# 18:00:03,192 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 18:00:02,985 [Thread-1] INFO  CalculationEngine:    'C.-M. Arvhult, Optimized ELRS
#
# 18:00:03,102 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 18:00:02,971 [Thread-1] INFO  CalculationEngine:    'C.-M. Arvhult, Optimized ELRS
#
# 18:00:02,985 [Thread-1] INFO  CalculationEngine:         THCD, Thermo-Calc Software. '
#
# 18:00:03,192 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 18:00:02,971 [Thread-1] INFO  CalculationEngine:         THCD, Thermo-Calc Software. '
#
# 18:00:03,102 [Thread-1] INFO  CalculationEngine:    'M J Assael, J Phys Chem Ref Data 35 (2006) 285; Fe, Al'
#
# 18:00:02,972 [Thread-1] INFO  CalculationEngine:    'H-L Chen, in TCAL7.0, Evaluation and modeling of electrical resistivity
#
# 18:00:03,103 [Thread-1] INFO  CalculationEngine:    'R Zhang, Thermo-Calc Software AB: assessing the viscosity of molten
#
# 18:00:03,197 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 18:00:02,985 [Thread-1] INFO  CalculationEngine:    'H-L Chen, in TCAL7.0, Evaluation and modeling of electrical resistivity
#
# 18:00:03,103 [Thread-1] INFO  CalculationEngine:        oxides, 2019'
#
# 18:00:02,972 [Thread-1] INFO  CalculationEngine:         thermal conductivity'
#
# 18:00:03,197 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 18:00:03,103 [Thread-1] INFO  CalculationEngine:    'Same or similar interaction as in the corresponding stable phase'
#
# 18:00:02,985 [Thread-1] INFO  CalculationEngine:         thermal conductivity'
#
# 18:00:02,972 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software, 2020: ELRS/THCD of liquid'
#
# 18:00:03,197 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 18:00:03,103 [Thread-1] INFO  CalculationEngine:    'C.-M. Arvhult, Optimized ELRS
#
# 18:00:03,197 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 18:00:02,972 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB (2020): assessing the surface tension
#
# 18:00:02,986 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software, 2020: ELRS/THCD of liquid'
#
# 18:00:03,198 [Thread-1] INFO  CalculationEngine:    'M J Assael, J Phys Chem Ref Data 35 (2006) 285; Fe, Al'
#
# 18:00:03,104 [Thread-1] INFO  CalculationEngine:         THCD, Thermo-Calc Software. '
#
# 18:00:02,972 [Thread-1] INFO  CalculationEngine:        of metallic liquid'
#
# 18:00:02,986 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB (2020): assessing the surface tension
#
# 18:00:03,198 [Thread-1] INFO  CalculationEngine:    'R Zhang, Thermo-Calc Software AB: assessing the viscosity of molten
#
# 18:00:03,104 [Thread-1] INFO  CalculationEngine:    'H-L Chen, in TCAL7.0, Evaluation and modeling of electrical resistivity
#
# 18:00:03,104 [Thread-1] INFO  CalculationEngine:         thermal conductivity'
#
# 18:00:02,973 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden 2023; Reassessment of surface
#
# 18:00:02,986 [Thread-1] INFO  CalculationEngine:        of metallic liquid'
#
# 18:00:02,973 [Thread-1] INFO  CalculationEngine:        tension using RK rule'
#
# 18:00:03,104 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software, 2020: ELRS/THCD of liquid'
#
# 18:00:02,986 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden 2023; Reassessment of surface
#
# 18:00:02,973 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Surface tensions for oxide liquid in TCOX, Thermo-Calc Software
#
# 18:00:03,204 [Thread-1] INFO  CalculationEngine:        oxides, 2019'
#
# 18:00:03,104 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB (2020): assessing the surface tension
#
# 18:00:02,973 [Thread-1] INFO  CalculationEngine:        AB, Sweden, 2020-2022'
#
# 18:00:03,204 [Thread-1] INFO  CalculationEngine:    'Same or similar interaction as in the corresponding stable phase'
#
# 18:00:02,986 [Thread-1] INFO  CalculationEngine:        tension using RK rule'
#
# 18:00:03,105 [Thread-1] INFO  CalculationEngine:        of metallic liquid'
#
# 18:00:02,986 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Surface tensions for oxide liquid in TCOX, Thermo-Calc Software
#
# 18:00:03,204 [Thread-1] INFO  CalculationEngine:    'C.-M. Arvhult, Optimized ELRS
#
# 18:00:03,105 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden 2023; Reassessment of surface
#
# 18:00:03,105 [Thread-1] INFO  CalculationEngine:        tension using RK rule'
#
# 18:00:02,986 [Thread-1] INFO  CalculationEngine:        AB, Sweden, 2020-2022'
#
# 18:00:03,204 [Thread-1] INFO  CalculationEngine:         THCD, Thermo-Calc Software. '
#
# 18:00:03,105 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Surface tensions for oxide liquid in TCOX, Thermo-Calc Software
#
# 18:00:03,205 [Thread-1] INFO  CalculationEngine:    'H-L Chen, in TCAL7.0, Evaluation and modeling of electrical resistivity
#
# 18:00:03,105 [Thread-1] INFO  CalculationEngine:        AB, Sweden, 2020-2022'
#
# 18:00:03,205 [Thread-1] INFO  CalculationEngine:         thermal conductivity'
#
# 18:00:03,205 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software, 2020: ELRS/THCD of liquid'
#
# 18:00:03,206 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB (2020): assessing the surface tension
#
# 18:00:03,206 [Thread-1] INFO  CalculationEngine:        of metallic liquid'
#
# 18:00:03,206 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden 2023; Reassessment of surface
#
# 18:00:03,206 [Thread-1] INFO  CalculationEngine:        tension using RK rule'
#
# 18:00:03,206 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Surface tensions for oxide liquid in TCOX, Thermo-Calc Software
#
# 18:00:03,206 [Thread-1] INFO  CalculationEngine:        AB, Sweden, 2020-2022'
#
# 18:00:03,663 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 18:00:03,668 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 18:00:03,669 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 18:00:03,669 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 18:00:03,669 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 18:00:03,669 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 18:00:03,669 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 18:00:03,670 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 18:00:03,670 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 18:00:03,670 [Thread-1] INFO  CalculationEngine:    'M J Assael, J Phys Chem Ref Data 35 (2006) 285; Fe, Al'
#
# 18:00:03,670 [Thread-1] INFO  CalculationEngine:    'R Zhang, Thermo-Calc Software AB: assessing the viscosity of molten
#
# 18:00:03,896 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 18:00:03,671 [Thread-1] INFO  CalculationEngine:        oxides, 2019'
#
# 18:00:03,898 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 18:00:03,671 [Thread-1] INFO  CalculationEngine:    'Same or similar interaction as in the corresponding stable phase'
#
# 18:00:03,898 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 18:00:03,671 [Thread-1] INFO  CalculationEngine:    'C.-M. Arvhult, Optimized ELRS
#
# 18:00:03,671 [Thread-1] INFO  CalculationEngine:         THCD, Thermo-Calc Software. '
#
# 18:00:03,898 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 18:00:03,671 [Thread-1] INFO  CalculationEngine:    'H-L Chen, in TCAL7.0, Evaluation and modeling of electrical resistivity
#
# 18:00:03,898 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 18:00:03,671 [Thread-1] INFO  CalculationEngine:         thermal conductivity'
#
# 18:00:03,898 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 18:00:03,672 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software, 2020: ELRS/THCD of liquid'
#
# 18:00:03,898 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 18:00:03,672 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB (2020): assessing the surface tension
#
# 18:00:03,899 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 18:00:03,672 [Thread-1] INFO  CalculationEngine:        of metallic liquid'
#
# 18:00:03,899 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 18:00:03,672 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden 2023; Reassessment of surface
#
# 18:00:03,899 [Thread-1] INFO  CalculationEngine:    'M J Assael, J Phys Chem Ref Data 35 (2006) 285; Fe, Al'
#
# 18:00:03,672 [Thread-1] INFO  CalculationEngine:        tension using RK rule'
#
# 18:00:04,090 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 18:00:03,899 [Thread-1] INFO  CalculationEngine:    'R Zhang, Thermo-Calc Software AB: assessing the viscosity of molten
#
# 18:00:04,095 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 18:00:03,672 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Surface tensions for oxide liquid in TCOX, Thermo-Calc Software
#
# 18:00:03,899 [Thread-1] INFO  CalculationEngine:        oxides, 2019'
#
# 18:00:04,096 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 18:00:04,096 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 18:00:03,899 [Thread-1] INFO  CalculationEngine:    'Same or similar interaction as in the corresponding stable phase'
#
# 18:00:03,673 [Thread-1] INFO  CalculationEngine:        AB, Sweden, 2020-2022'
#
# 18:00:03,899 [Thread-1] INFO  CalculationEngine:    'C.-M. Arvhult, Optimized ELRS
#
# 18:00:04,096 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 18:00:03,900 [Thread-1] INFO  CalculationEngine:         THCD, Thermo-Calc Software. '
#
# 18:00:04,097 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 18:00:03,900 [Thread-1] INFO  CalculationEngine:    'H-L Chen, in TCAL7.0, Evaluation and modeling of electrical resistivity
#
# 18:00:04,097 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 18:00:03,900 [Thread-1] INFO  CalculationEngine:         thermal conductivity'
#
# 18:00:04,097 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 18:00:04,097 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 18:00:03,900 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software, 2020: ELRS/THCD of liquid'
#
# 18:00:04,097 [Thread-1] INFO  CalculationEngine:    'M J Assael, J Phys Chem Ref Data 35 (2006) 285; Fe, Al'
#
# 18:00:03,900 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB (2020): assessing the surface tension
#
# 18:00:04,098 [Thread-1] INFO  CalculationEngine:    'R Zhang, Thermo-Calc Software AB: assessing the viscosity of molten
#
# 18:00:03,900 [Thread-1] INFO  CalculationEngine:        of metallic liquid'
#
# 18:00:04,296 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 18:00:04,098 [Thread-1] INFO  CalculationEngine:        oxides, 2019'
#
# 18:00:03,900 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden 2023; Reassessment of surface
#
# 18:00:04,098 [Thread-1] INFO  CalculationEngine:    'Same or similar interaction as in the corresponding stable phase'
#
# 18:00:03,900 [Thread-1] INFO  CalculationEngine:        tension using RK rule'
#
# 18:00:04,297 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 18:00:04,098 [Thread-1] INFO  CalculationEngine:    'C.-M. Arvhult, Optimized ELRS
#
# 18:00:04,099 [Thread-1] INFO  CalculationEngine:         THCD, Thermo-Calc Software. '
#
# 18:00:03,901 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Surface tensions for oxide liquid in TCOX, Thermo-Calc Software
#
# 18:00:04,298 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 18:00:03,901 [Thread-1] INFO  CalculationEngine:        AB, Sweden, 2020-2022'
#
# 18:00:04,099 [Thread-1] INFO  CalculationEngine:    'H-L Chen, in TCAL7.0, Evaluation and modeling of electrical resistivity
#
# 18:00:04,099 [Thread-1] INFO  CalculationEngine:         thermal conductivity'
#
# 18:00:04,298 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 18:00:04,099 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software, 2020: ELRS/THCD of liquid'
#
# 18:00:04,298 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 18:00:04,100 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB (2020): assessing the surface tension
#
# 18:00:04,298 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 18:00:04,100 [Thread-1] INFO  CalculationEngine:        of metallic liquid'
#
# 18:00:04,298 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 18:00:04,100 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden 2023; Reassessment of surface
#
# 18:00:04,100 [Thread-1] INFO  CalculationEngine:        tension using RK rule'
#
# 18:00:04,299 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 18:00:04,100 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Surface tensions for oxide liquid in TCOX, Thermo-Calc Software
#
# 18:00:04,299 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 18:00:04,489 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 18:00:04,100 [Thread-1] INFO  CalculationEngine:        AB, Sweden, 2020-2022'
#
# 18:00:04,299 [Thread-1] INFO  CalculationEngine:    'M J Assael, J Phys Chem Ref Data 35 (2006) 285; Fe, Al'
#
# 18:00:04,490 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 18:00:04,299 [Thread-1] INFO  CalculationEngine:    'R Zhang, Thermo-Calc Software AB: assessing the viscosity of molten
#
# 18:00:04,491 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 18:00:04,544 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 18:00:04,504 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 18:00:04,299 [Thread-1] INFO  CalculationEngine:        oxides, 2019'
#
# 18:00:04,545 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 18:00:04,504 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 18:00:04,546 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 18:00:04,299 [Thread-1] INFO  CalculationEngine:    'Same or similar interaction as in the corresponding stable phase'
#
# 18:00:04,504 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 18:00:04,546 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 18:00:04,300 [Thread-1] INFO  CalculationEngine:    'C.-M. Arvhult, Optimized ELRS
#
# 18:00:04,504 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 18:00:04,616 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 18:00:04,300 [Thread-1] INFO  CalculationEngine:         THCD, Thermo-Calc Software. '
#
# 18:00:04,504 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 18:00:04,546 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 18:00:04,622 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 18:00:04,300 [Thread-1] INFO  CalculationEngine:    'H-L Chen, in TCAL7.0, Evaluation and modeling of electrical resistivity
#
# 18:00:04,546 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 18:00:04,504 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 18:00:04,546 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 18:00:04,505 [Thread-1] INFO  CalculationEngine:    'M J Assael, J Phys Chem Ref Data 35 (2006) 285; Fe, Al'
#
# 18:00:04,300 [Thread-1] INFO  CalculationEngine:         thermal conductivity'
#
# 18:00:04,623 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 18:00:04,546 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 18:00:04,505 [Thread-1] INFO  CalculationEngine:    'R Zhang, Thermo-Calc Software AB: assessing the viscosity of molten
#
# 18:00:04,300 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software, 2020: ELRS/THCD of liquid'
#
# 18:00:04,623 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 18:00:04,546 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 18:00:04,505 [Thread-1] INFO  CalculationEngine:        oxides, 2019'
#
# 18:00:04,679 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 18:00:04,692 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 18:00:04,505 [Thread-1] INFO  CalculationEngine:    'Same or similar interaction as in the corresponding stable phase'
#
# 18:00:04,624 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 18:00:04,308 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB (2020): assessing the surface tension
#
# 18:00:04,684 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 18:00:04,697 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 18:00:04,624 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 18:00:04,546 [Thread-1] INFO  CalculationEngine:    'M J Assael, J Phys Chem Ref Data 35 (2006) 285; Fe, Al'
#
# 18:00:04,685 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 18:00:04,505 [Thread-1] INFO  CalculationEngine:    'C.-M. Arvhult, Optimized ELRS
#
# 18:00:04,698 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 18:00:04,624 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 18:00:04,547 [Thread-1] INFO  CalculationEngine:    'R Zhang, Thermo-Calc Software AB: assessing the viscosity of molten
#
# 18:00:04,308 [Thread-1] INFO  CalculationEngine:        of metallic liquid'
#
# 18:00:04,685 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 18:00:04,698 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 18:00:04,505 [Thread-1] INFO  CalculationEngine:         THCD, Thermo-Calc Software. '
#
# 18:00:04,624 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 18:00:04,308 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden 2023; Reassessment of surface
#
# 18:00:04,505 [Thread-1] INFO  CalculationEngine:    'H-L Chen, in TCAL7.0, Evaluation and modeling of electrical resistivity
#
# 18:00:04,699 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 18:00:04,308 [Thread-1] INFO  CalculationEngine:        tension using RK rule'
#
# 18:00:04,624 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 18:00:04,547 [Thread-1] INFO  CalculationEngine:        oxides, 2019'
#
# 18:00:04,547 [Thread-1] INFO  CalculationEngine:    'Same or similar interaction as in the corresponding stable phase'
#
# 18:00:04,685 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 18:00:04,308 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Surface tensions for oxide liquid in TCOX, Thermo-Calc Software
#
# 18:00:04,686 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 18:00:04,624 [Thread-1] INFO  CalculationEngine:    'M J Assael, J Phys Chem Ref Data 35 (2006) 285; Fe, Al'
#
# 18:00:04,699 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 18:00:04,506 [Thread-1] INFO  CalculationEngine:         thermal conductivity'
#
# 18:00:04,506 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software, 2020: ELRS/THCD of liquid'
#
# 18:00:04,699 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 18:00:04,547 [Thread-1] INFO  CalculationEngine:    'C.-M. Arvhult, Optimized ELRS
#
# 18:00:04,787 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 18:00:04,686 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 18:00:04,309 [Thread-1] INFO  CalculationEngine:        AB, Sweden, 2020-2022'
#
# 18:00:04,547 [Thread-1] INFO  CalculationEngine:         THCD, Thermo-Calc Software. '
#
# 18:00:04,699 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 18:00:04,625 [Thread-1] INFO  CalculationEngine:    'R Zhang, Thermo-Calc Software AB: assessing the viscosity of molten
#
# 18:00:04,686 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 18:00:04,506 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB (2020): assessing the surface tension
#
# 18:00:04,699 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 18:00:04,625 [Thread-1] INFO  CalculationEngine:        oxides, 2019'
#
# 18:00:04,547 [Thread-1] INFO  CalculationEngine:    'H-L Chen, in TCAL7.0, Evaluation and modeling of electrical resistivity
#
# 18:00:04,789 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 18:00:04,686 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 18:00:04,789 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 18:00:04,699 [Thread-1] INFO  CalculationEngine:    'M J Assael, J Phys Chem Ref Data 35 (2006) 285; Fe, Al'
#
# 18:00:04,506 [Thread-1] INFO  CalculationEngine:        of metallic liquid'
#
# 18:00:04,625 [Thread-1] INFO  CalculationEngine:    'Same or similar interaction as in the corresponding stable phase'
#
# 18:00:04,686 [Thread-1] INFO  CalculationEngine:    'M J Assael, J Phys Chem Ref Data 35 (2006) 285; Fe, Al'
#
# 18:00:04,506 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden 2023; Reassessment of surface
#
# 18:00:04,547 [Thread-1] INFO  CalculationEngine:         thermal conductivity'
#
# 18:00:04,700 [Thread-1] INFO  CalculationEngine:    'R Zhang, Thermo-Calc Software AB: assessing the viscosity of molten
#
# 18:00:04,686 [Thread-1] INFO  CalculationEngine:    'R Zhang, Thermo-Calc Software AB: assessing the viscosity of molten
#
# 18:00:04,789 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 18:00:04,625 [Thread-1] INFO  CalculationEngine:    'C.-M. Arvhult, Optimized ELRS
#
# 18:00:04,547 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software, 2020: ELRS/THCD of liquid'
#
# 18:00:04,700 [Thread-1] INFO  CalculationEngine:        oxides, 2019'
#
# 18:00:04,866 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 18:00:04,506 [Thread-1] INFO  CalculationEngine:        tension using RK rule'
#
# 18:00:04,626 [Thread-1] INFO  CalculationEngine:         THCD, Thermo-Calc Software. '
#
# 18:00:04,687 [Thread-1] INFO  CalculationEngine:        oxides, 2019'
#
# 18:00:04,789 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 18:00:04,700 [Thread-1] INFO  CalculationEngine:    'Same or similar interaction as in the corresponding stable phase'
#
# 18:00:04,869 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 18:00:04,548 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB (2020): assessing the surface tension
#
# 18:00:04,506 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Surface tensions for oxide liquid in TCOX, Thermo-Calc Software
#
# 18:00:04,790 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 18:00:04,626 [Thread-1] INFO  CalculationEngine:    'H-L Chen, in TCAL7.0, Evaluation and modeling of electrical resistivity
#
# 18:00:04,687 [Thread-1] INFO  CalculationEngine:    'Same or similar interaction as in the corresponding stable phase'
#
# 18:00:04,701 [Thread-1] INFO  CalculationEngine:    'C.-M. Arvhult, Optimized ELRS
#
# 18:00:04,626 [Thread-1] INFO  CalculationEngine:         thermal conductivity'
#
# 18:00:04,869 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 18:00:04,548 [Thread-1] INFO  CalculationEngine:        of metallic liquid'
#
# 18:00:04,790 [Thread-1] INFO  CalculationEngine:    'R. Naraghi, Thermo-Calc Software AB, Sweden, Volume data updated for
#
# 18:00:04,548 [Thread-1] INFO  CalculationEngine:    'R. Zhang, Thermo-Calc Software AB, Sweden 2023; Reassessment of surface
#
# 18:00:04,687 [Thread-1] INFO  CalculationEngine:    'C.-M. Arvhult, Optimized ELRS
#
# 18:00:04,507 [Thread-1] INFO  CalculationEngine:        AB, Sweden, 2020-2022'
#
# 18:00:04,701 [Thread-1] INFO  CalculationEngine:         THCD, Thermo-Calc Software. '
#
# 18:00:04,923 [Thread-1] INFO  CalculationEngine:    'A.T. Dinsdale, SGTE Data for Pure Elements, CALPHAD, 15 (1991) 317-425'
#
# 18:00:04,870 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 18:00:04,790 [Thread-1] INFO  CalculationEngine:        TCFE8 database (TCFE v8, May, 2015).'
#
# 18:00:04,626 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software, 2020: ELRS/THCD of liquid'
#
# 18:00:04,790 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, Thermo-Calc Software AB, Sweden, 2006; Molar volumes'
#
# 18:00:04,925 [Thread-1] INFO  CalculationEngine:    'Y. Tang, in TCCU2, Thermo-Calc Software AB, Stockholm, Sweden'
#
# 18:00:04,548 [Thread-1] INFO  CalculationEngine:        tension using RK rule'
#
# 18:00:04,687 [Thread-1] INFO  CalculationEngine:         THCD, Thermo-Calc Software. '
#
# 18:00:04,627 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software AB (2020): assessing the surface tension
#
# 18:00:04,701 [Thread-1] INFO  CalculationEngine:    'H-L Chen, in TCAL7.0, Evaluation and modeling of electrical resistivity
#
# 18:00:04,870 [Thread-1] INFO  CalculationEngine:    'M. Kowalski and P.J. Spencer, Calphad 19 (1995) 229-243; Cr-O, Fe-O and
#
# 18:00:04,925 [Thread-1] INFO  CalculationEngine:    'X.G. Lu, M. Selleby and B. Sundman, CALPHAD, 29, 2005, 68-89; Molar
#
# 18:00:04,701 [Thread-1] INFO  CalculationEngine:         thermal conductivity'
#
# 18:00:04,688 [Thread-1] INFO  CalculationEngine:    'H-L Chen, in TCAL7.0, Evaluation and modeling of electrical resistivity
#
# 18:00:04,870 [Thread-1] INFO  CalculationEngine:        Ni-O'
#
# 18:00:04,790 [Thread-1] INFO  CalculationEngine:    'M J Assael, J Phys Chem Ref Data 35 (2006) 285; Fe, Al'
#
# 18:00:04,925 [Thread-1] INFO  CalculationEngine:        volumes'
#
# 18:00:04,627 [Thread-1] INFO  CalculationEngine:        of metallic liquid'
#
# 18:00:04,688 [Thread-1] INFO  CalculationEngine:         thermal conductivity'
#
# 18:00:04,702 [Thread-1] INFO  CalculationEngine:    'M Ghasemi, Thermo-Calc Software, 2020: ELRS/THCD of liquid'
#
# ...
#
# 18:04:04,303 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 18:04:04,302 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:04,323 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 18:04:04,359 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:04,428 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 18:04:04,425 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 18:04:04,517 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 18:04:04,539 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 18:04:04,662 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 18:04:04,690 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:04,755 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 18:04:04,788 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 18:04:04,873 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 18:04:04,873 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 18:04:04,913 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:04,998 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 18:04:05,197 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 18:04:05,305 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:05,315 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 18:04:05,321 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:05,328 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:05,302 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:05,361 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:05,381 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:05,560 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:05,681 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:05,716 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:05,762 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:05,797 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:05,823 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:05,859 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:05,963 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 18:04:06,103 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:06,140 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:06,189 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:06,204 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:06,249 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:06,260 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:06,293 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:06,360 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:06,409 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:06,421 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:06,448 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 18:04:06,477 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:06,565 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:06,578 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:06,597 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:06,633 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:06,622 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 18:04:06,647 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:06,699 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 18:04:06,815 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:06,828 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:06,870 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:06,882 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:06,911 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:06,916 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:07,014 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:07,004 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 18:04:07,013 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:07,065 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:07,094 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 18:04:07,207 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:07,216 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:07,221 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:07,232 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:07,241 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:07,282 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:07,273 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:07,320 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:07,329 [Thread-1] INFO  CalculationEngine: Starting Thermo-Calc 2023b, Java-version: 14.0.2
#
# 18:04:07,341 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:07,343 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:07,344 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:07,364 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:07,394 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:07,419 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:07,430 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:07,486 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:07,532 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:07,568 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:07,621 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:07,632 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:07,702 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:07,736 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:07,749 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:07,790 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:07,798 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:07,821 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:07,822 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:07,864 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:07,902 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:07,904 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:07,928 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:07,937 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:07,940 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:07,946 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:07,978 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:07,980 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:08,002 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:08,030 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:08,062 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:08,086 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:08,082 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:08,128 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:08,127 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:08,186 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:08,226 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:08,219 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:08,239 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:08,267 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:08,270 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:08,366 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:08,378 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:08,384 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:08,393 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:08,431 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:08,485 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:08,529 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:08,522 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:08,577 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:08,666 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:08,672 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:08,827 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:08,875 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:08,952 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:09,109 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:09,110 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:09,120 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:09,132 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:09,153 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:09,184 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:09,260 [Thread-1] INFO  SystemBuilder: Found matching previous system
#
# 18:04:09,264 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:09,312 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:09,467 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:09,506 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:09,509 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:09,536 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:09,624 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# 18:04:09,653 [pool-4-thread-1] INFO  CalculationEngine: Performing batch equilibrium calculation. Logging every 100th equilibrium...
#
# Time taken:  283 seconds

# %% [markdown]
# #### checking results

# %%
# check again how many processes:
print("number of processes - FullEquil: ", len(FullEquil_results))
print("number of processes - Gmin: ", len(Gmin_results))
print("number of processes - DGM: ", len(DGM_results))

# in each process: list_of_conditions+'np(CORUNDUM)'+'np(SPINEL)'+'np(HALITE)'+'np(BCC_A2)'+'np(LIQUID)'
print("#data categories in each process - FullEquil: ",
      len(FullEquil_results[0]))

# in each process: list_of_conditions+'gm(phase)'
print("#data categories in each process - Gmin: ", len(Gmin_results[0]))

# in each process: list_of_conditions+'dgm(phase)'
print("#data categories in each process - DGM: ",  len(DGM_results[0]))

# the data length inside the above outputs categories
print("data length inside - FullEquil: ", len(FullEquil_results[0][0]))
print("data length inside - Gmin: ", len(Gmin_results[0][1]))
print("data length inside - DGM: ", len(DGM_results[0][1]))
# Out:
# number of processes - FullEquil:  121
# number of processes - Gmin:  605
# number of processes - DGM:  605
# #data categories in each process - FullEquil:  6
# #data categories in each process - Gmin:  2
# #data categories in each process - DGM:  2
# data length inside - FullEquil:  150
# data length inside - Gmin:  150
# data length inside - DGM:  150

# %% [markdown]
# ### Unpack the calculation results

# %% [markdown]
# #### Analyse FullEquil results

# %%
# Merge results from different processes
list_of_conditions = [res[0] for res in FullEquil_results]
list_np_CORUNDUM = [res[1] for res in FullEquil_results]
list_np_SPINEL = [res[2] for res in FullEquil_results]
list_np_HALITE = [res[3] for res in FullEquil_results]
list_np_BCC_A2 = [res[4] for res in FullEquil_results]
list_np_LIQUID = [res[5] for res in FullEquil_results]

# print(len(list_of_conditions))

# Flattening the lists
list_of_conditions = [
    item for sublist in list_of_conditions for item in sublist]
list_np_CORUNDUM = [item for sublist in list_np_CORUNDUM for item in sublist]
list_np_SPINEL = [item for sublist in list_np_SPINEL for item in sublist]
list_np_HALITE = [item for sublist in list_np_HALITE for item in sublist]
list_np_BCC_A2 = [item for sublist in list_np_BCC_A2 for item in sublist]
list_np_LIQUID = [item for sublist in list_np_LIQUID for item in sublist]

# print(len(list_of_conditions))

# list_np_FCC_L12_merge = [max(a, b, c) for a, b, c in zip(
#     list_np_FCC_L12, list_np_FCC_L12_1, list_np_FCC_L12_2)]

df_FullEquil = pd.DataFrame(columns=['lnacr_o', 'T', 'np(CORUNDUM)',
                                     'np(SPINEL)', 'np(HALITE)', 'np(BCC_A2)', 'np(LIQUID)'])

# Convert conditions and results to DataFrame
df_FullEquil = pd.DataFrame({
    'lnacr_o': [dict(conditions)['lnacr(o)'] for conditions in list_of_conditions],
    'T': [dict(conditions)['T'] for conditions in list_of_conditions],
    'np(CORUNDUM)': list_np_CORUNDUM,
    'np(SPINEL)': list_np_SPINEL,
    'np(HALITE)': list_np_HALITE,
    'np(BCC_A2)': list_np_BCC_A2,
    'np(LIQUID)': list_np_LIQUID
})

df_FullEquil.to_excel(os.path.join(current_directory,
                                   "tc_df_FullEquil_check.xlsx"), index=False)

display(df_FullEquil.head(3), df_FullEquil.shape)
# Out:
#      lnacr_o       T  np(CORUNDUM)  np(SPINEL)  np(HALITE)  np(BCC_A2)  \
# 0 -60.000000  273.15           1.0         0.0         0.0         0.0
# 1 -59.630872  273.15           1.0         0.0         0.0         0.0
# 2 -59.261745  273.15           1.0         0.0         0.0         0.0
#
#    np(LIQUID)
# 0         0.0
# 1         0.0
# 2         0.0
# (18150, 7)

# %% [markdown]
# #### Analyse Gmin results

# %%
from copy import deepcopy


def process_data(Gmin_DGM_args, Gmin_DGM_results):

    Gmin_gm_values = {}
    Gmin_phase_conditions = {}

    for args, result in zip(Gmin_DGM_args, Gmin_DGM_results):
        tk, db, phase = deepcopy(args)
        conditions, gm_values = deepcopy(result)

        lnacr_o_values = [dict(cond)['lnacr(o)'] for cond in conditions]
        T_values = [dict(cond)['T'] for cond in conditions]

        if phase in Gmin_gm_values:
            Gmin_gm_values[phase].extend(gm_values)
        else:
            Gmin_gm_values[phase] = gm_values

        if phase in Gmin_phase_conditions:
            Gmin_phase_conditions[phase]['lnacr(o)'].extend(lnacr_o_values)
            Gmin_phase_conditions[phase]['T'].extend(T_values)
        else:
            Gmin_phase_conditions[phase] = {
                'lnacr(o)': lnacr_o_values, 'T': T_values}

    return Gmin_gm_values, Gmin_phase_conditions

# %%
phases_list = [phase for db_phases in databases_phases.values()
               for phase in db_phases]
print(phases_list)

print("Length of Gmin_DGM_args:", len(Gmin_DGM_args))
print("Length of Gmin_results:", len(Gmin_results))

Gmin_gm_values, Gmin_phase_conditions = process_data(
    Gmin_DGM_args, Gmin_results)

print("temperature_grid x acc_grid:", 130*250)
print("length of Gmin_gm_values: ", len(Gmin_gm_values['BCC_A2']))

for i, phase in enumerate(phases_list):
    assert Gmin_phase_conditions[phases_list[0]
                                 ] == Gmin_phase_conditions[phase]

Gmin_conditions = Gmin_phase_conditions[phases_list[0]]
print("length of Gmin_conditions: ", len(Gmin_conditions['lnacr(o)']))
# Out:
# ['CORUNDUM', 'SPINEL', 'HALITE', 'BCC_A2', 'LIQUID']
# Length of Gmin_DGM_args: 605
# Length of Gmin_results: 605
# temperature_grid x acc_grid: 32500
# length of Gmin_gm_values:  18150
# length of Gmin_conditions:  18150

# %%
df_Gmin = pd.DataFrame({
    'lnacr_o':  Gmin_conditions['lnacr(o)'],
    'T': Gmin_conditions['T'],
    **{f'gm({phase})': Gmin_gm_values.get(phase, []) for phase in phases_list}
})

df_Gmin.to_excel(os.path.join(current_directory,
                 "tc_df_Gmin_check.xlsx"), index=False)

display(df_Gmin.head(3), df_Gmin.shape)
# Out:
#      lnacr_o       T   gm(CORUNDUM)     gm(SPINEL)     gm(HALITE)  \
# 0 -60.000000  273.15 -169478.616352 -165399.993875 -165434.629564
# 1 -59.630872  273.15 -169478.616352 -165403.624199 -165434.629612
# 2 -59.261745  273.15 -169478.616352 -165404.374245 -165434.629620
#
#     gm(BCC_A2)     gm(LIQUID)
# 0 -24490.49248 -153732.971103
# 1 -25308.13219 -153732.973241
# 2 -26118.02405 -153732.974902
# (18150, 7)

# %% [markdown]
# #### Analyse NormDrivingForce results

# %%
print("Length of Gmin_DGM_args:", len(Gmin_DGM_args))
print("Length of DGM_results:", len(DGM_results))

DGM_dgm_values, DGM_phase_conditions = process_data(
    Gmin_DGM_args, DGM_results)

print("temperature_grid x acc_grid:", 130*250)
print("length of DGM_dgm_values: ", len(DGM_dgm_values['BCC_A2']))

for i, phase in enumerate(phases_list):
    assert DGM_phase_conditions[phases_list[0]
                                ] == DGM_phase_conditions[phase]

DGM_conditions = DGM_phase_conditions[phases_list[0]]
print("length of DGM_conditions: ", len(DGM_conditions['lnacr(o)']))
# Out:
# Length of Gmin_DGM_args: 605
# Length of DGM_results: 605
# temperature_grid x acc_grid: 32500
# length of DGM_dgm_values:  18150
# length of DGM_conditions:  18150

# %%
df_DGM = pd.DataFrame({
    'lnacr_o':  DGM_conditions['lnacr(o)'],
    'T': DGM_conditions['T'],
    **{f'dgm({phase})': DGM_dgm_values.get(phase, []) for phase in phases_list}
})

df_DGM.to_excel(os.path.join(current_directory,
                             "tc_df_DGM_check.xlsx"), index=False)

display(df_DGM.head(3), df_DGM.shape)
# Out:
#      lnacr_o       T  dgm(CORUNDUM)  dgm(SPINEL)  dgm(HALITE)  dgm(BCC_A2)  \
# 0 -60.000000  273.15      69.825806    71.771782    74.319791    91.623922
# 1 -59.630872  273.15      70.047282    71.956346    74.504355    91.134553
# 2 -59.261745  273.15      70.268759    72.140909    74.688918    90.648742
#
#    dgm(LIQUID)
# 0    62.892852
# 1    63.114317
# 2    63.335785
# (18150, 7)

# %% [markdown]
# ### FullEquil: steping at one temperature

# %%
# Filter the dataframe for rows where T is 573.15
filtered_df_FullEquil = df_FullEquil[df_FullEquil['T'] == 573.15]
filtered_df_FullEquil.to_excel(os.path.join(current_directory,
                                            "tc_df_FullEquil_check_filter.xlsx"), index=False)

plt.figure(figsize=(5, 5))
colors = {
    'CORUNDUM': '#48A36D',
    'SPINEL': '#3288BD',
    'HALITE': '#756BB1',
    'BCC_A2': '#E68A00',
    'LIQUID': '#D43E4F'
}
labels_list = ['Hematite', 'Magnetite', 'Wustite', 'BCC Iron', 'Liquid']


plt.plot(filtered_df_FullEquil['lnacr_o'], filtered_df_FullEquil['np(CORUNDUM)'],
         color=colors['CORUNDUM'], label='CORUNDUM')
plt.plot(filtered_df_FullEquil['lnacr_o'], filtered_df_FullEquil['np(SPINEL)'],
         color=colors['SPINEL'], label='SPINEL')
# plt.plot(filtered_df_FullEquil['lnacr_o'], filtered_df_FullEquil['np(HALITE)'],
#          color=colors['HALITE'], label='HALITE')
plt.plot(filtered_df_FullEquil['lnacr_o'], filtered_df_FullEquil['np(BCC_A2)'],
         color=colors['BCC_A2'], label='BCC_A2')
# plt.plot(filtered_df_FullEquil['lnacr_o'], filtered_df_FullEquil['np(LIQUID)'],
#          color=colors['LIQUID'], label='LIQUID')

plt.xlabel('Natural log of oxygen activity')
plt.ylabel('Mole fraction')
plt.grid(True)
plt.legend()
# plt.xlim(-100, -25)
plt.show()

# %% [markdown]
# ### FullEquil: mapping for one phase

# %%
plt.figure(figsize=(5, 5))
plt.scatter(df_FullEquil['lnacr_o'], df_FullEquil['T']-273.15,
            c=df_FullEquil['np(CORUNDUM)'], s=6,  alpha=1)
plt.xlabel(df_FullEquil.columns[0])
plt.ylabel(df_FullEquil.columns[1])
plt.grid(True)
plt.title('check and plotting the Hematite')
plt.show()

# %% [markdown]
# ### FullEquil: Mapping for all phases

# %%
# Splitting the main dataframe into individual dataframes and filtering them
df_FullEquil_CORUNDUM = df_FullEquil[['lnacr_o', 'T', 'np(CORUNDUM)']]
df_FullEquil_CORUNDUM = df_FullEquil_CORUNDUM[
    df_FullEquil_CORUNDUM['np(CORUNDUM)'] >= 0.001]

df_FullEquil_SPINEL = df_FullEquil[['lnacr_o', 'T', 'np(SPINEL)']]
df_FullEquil_SPINEL = df_FullEquil_SPINEL[
    df_FullEquil_SPINEL['np(SPINEL)'] >= 0.001]

df_FullEquil_HALITE = df_FullEquil[['lnacr_o', 'T', 'np(HALITE)']]
df_FullEquil_HALITE = df_FullEquil_HALITE[df_FullEquil_HALITE['np(HALITE)']
                                          >= 0.001]

df_FullEquil_BCC_A2 = df_FullEquil[['lnacr_o', 'T', 'np(BCC_A2)']]
df_FullEquil_BCC_A2 = df_FullEquil_BCC_A2[df_FullEquil_BCC_A2['np(BCC_A2)']
                                          >= 0.001]

df_FullEquil_LIQUID = df_FullEquil[['lnacr_o', 'T', 'np(LIQUID)']]
df_FullEquil_LIQUID = df_FullEquil_LIQUID[df_FullEquil_LIQUID['np(LIQUID)']
                                          >= 0.001]

# %%
# Plotting the individual dataframes
plt.figure(figsize=(5, 5))

for i, phase in enumerate(phases_list):
    if phase == "HALITE" or phase == "LIQUID":
        pass
    else:
        df = globals()[f'df_FullEquil_{phase}']
        plt.scatter(df['lnacr_o'], df['T']-273.15, s=12,
                    label=labels_list[i],
                    color=colors[phase], alpha=1)
plt.scatter([-7.9663978], [300], color='white')
plt.xlabel('Natural log of oxygen activity', fontsize=14)
plt.ylabel(r'T ($^\circ$C)', fontsize=14)
plt.title('Full Equilibrium', fontsize=14)
plt.legend(fontsize=12, loc='upper left',
           facecolor='white', edgecolor='black', framealpha=0.9)
plt.grid(True, which='both', linestyle='--', linewidth=0.4)
plt.xlim([min(df_Gmin['lnacr_o']), max(df_Gmin['lnacr_o'])])
plt.ylim([min(df_Gmin['T'])-273.15, max(df_Gmin['T'])-273.15])
plt.yticks(range(0, 601, 100))
plt.tight_layout()

plt_output_fname = "_FullEquil.png"
plt.savefig(os.path.join(current_directory, output_fname+plt_output_fname),
            format='png', dpi=300,  bbox_inches='tight', )
plt.show()

# %% [markdown]
# ### Gmin: mapping for individual phase

# %%
display(df_Gmin.head(3), df_Gmin.shape)
# Out:
#      lnacr_o       T   gm(CORUNDUM)     gm(SPINEL)     gm(HALITE)  \
# 0 -60.000000  273.15 -169478.616352 -165399.993875 -165434.629564
# 1 -59.630872  273.15 -169478.616352 -165403.624199 -165434.629612
# 2 -59.261745  273.15 -169478.616352 -165404.374245 -165434.629620
#
#     gm(BCC_A2)     gm(LIQUID)
# 0 -24490.49248 -153732.971103
# 1 -25308.13219 -153732.973241
# 2 -26118.02405 -153732.974902
# (18150, 7)

# %%
from matplotlib.ticker import ScalarFormatter

# Define the colormaps for each phase
colormaps = {
    'CORUNDUM': 'Greens',
    'SPINEL': 'Blues',
    'HALITE': 'Purples',
    'BCC_A2': 'YlOrBr',
    'LIQUID': 'RdPu'
}

# Create a new figure with subplots
fig, axs = plt.subplots(nrows=1, ncols=len(
    phases_list), figsize=(3.1 * len(phases_list), 3), sharex=True, sharey=True)

for i, phase in enumerate(phases_list):

    sc = axs[i].scatter(df_Gmin['lnacr_o'], df_Gmin['T']-273.15,
                        c=df_Gmin[f'gm({phase})'],
                        cmap=colormaps[phase], s=5, alpha=0.6)

    cbar = plt.colorbar(sc, ax=axs[i])

    # Change colorbar numbering to scientific notation
    formatter = ScalarFormatter(useMathText=True)
    formatter.set_scientific(True)
    formatter.set_powerlimits((-1, 1))
    cbar.ax.yaxis.set_major_formatter(formatter)

    # Label the colorbar of the last plot only
    if i == len(phases_list) - 1:
        cbar.set_label('molar Gibbs energy (J/mol)', fontsize=14)
    if i == 0:
        axs[i].set_ylabel(r'T ($^\circ$C)', fontsize=14)

    axs[i].set_xlabel('Natural log of oxygen activity', fontsize=14)
    axs[i].set_xlim([min(df_Gmin['lnacr_o']), max(df_Gmin['lnacr_o'])])
    axs[i].set_ylim([min(df_Gmin['T'])-273.15,
                     max(df_Gmin['T'])-273.15])
    axs[i].grid(True, which='both', linestyle='--', linewidth=0.5)
    axs[i].set_title(f'{labels_list[i]}')
    axs[i].set_yticks(range(200, 601, 100))
    # axs[i].set_aspect('equal', 'box')

plt.tight_layout()
plt_output_fname = "_Gm_phases.png"
plt.savefig(os.path.join(current_directory, output_fname+plt_output_fname),
            format='png', dpi=300,  bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Gmin: Mapping for all phases

# %%
columns_to_compare = [f'gm({phase})' for phase in phases_list]

for phase in phases_list:
    column_name = f'gm({phase})'
    condition = df_Gmin[column_name] == df_Gmin[columns_to_compare].min(axis=1)
    globals()[f'df_Gmin_{phase}'] = df_Gmin[condition]

# Plotting the individual dataframes
plt.figure(figsize=(5, 5))

for phase in phases_list:
    df = globals()[f'df_Gmin_{phase}']
    plt.scatter(df['lnacr_o'], df['T'], s=10, label=phase,
                color=colors[phase], alpha=1)

plt.xlabel('Natural log of oxygen activity', fontsize=14)
plt.ylabel(r'T ($^\circ$C)', fontsize=14)
plt.title('minimum Gibbs energy', fontsize=14)
plt.legend(fontsize=12, loc='upper left',
           facecolor='white', edgecolor='black', framealpha=0.9)
plt.grid(True, which='both', linestyle='--', linewidth=0.1)
plt.xlim([min(df_Gmin['lnacr_o']), max(df_Gmin['lnacr_o'])])
plt.ylim([min(df_Gmin['T']), max(df_Gmin['T'])])
plt.tight_layout()

# plt_output_fname = "_Gmin.png"
# plt.savefig(os.path.join(current_directory, output_fname+plt_output_fname),
#             format='png', dpi=300,  bbox_inches='tight')
plt.show()

# %% [markdown]
# ### NormDrivingForce: Mapping for individual phase

# %%
# Create a new figure with subplots
fig, axs = plt.subplots(nrows=1, ncols=len(
    phases_list), figsize=(3.1 * len(phases_list), 3), sharex=True, sharey=True)

for i, phase in enumerate(phases_list):

    sc = axs[i].scatter(df_DGM['lnacr_o'], df_DGM['T'],
                        c=df_DGM[f'dgm({phase})'], cmap=colormaps[phase], s=5, alpha=0.6)

    cbar = plt.colorbar(sc, ax=axs[i])

    # Change colorbar numbering to scientific notation
    formatter = ScalarFormatter(useMathText=True)
    formatter.set_scientific(True)
    formatter.set_powerlimits((-1, 1))
    cbar.ax.yaxis.set_major_formatter(formatter)

    # Label the colorbar of the last plot only
    if i == len(phases_list) - 1:
        cbar.set_label('Driving force normalised by RT', fontsize=14)

    axs[i].set_xlabel('Natural log of oxygen activity', fontsize=14)
    axs[i].set_ylabel(r'T ($^\circ$C)', fontsize=14)
    axs[i].set_xlim([min(df_DGM['lnacr_o']), max(df_DGM['lnacr_o'])])
    axs[i].set_ylim([min(df_DGM['T']), max(df_DGM['T'])])
    axs[i].grid(True, which='both', linestyle='--', linewidth=0.5)
    axs[i].set_title(f'{labels_list[i]}')
    # axs[i].set_aspect('equal', 'box')

plt.tight_layout()
plt_output_fname = "_DGM_phases.png"
plt.savefig(os.path.join(current_directory, output_fname+plt_output_fname),
            format='png', dpi=300,  bbox_inches='tight')
plt.show()

# %% [markdown]
# ### DGM: Mapping for all phases

# %%
columns_to_compare = [f'dgm({phase})' for phase in phases_list]
# columns_to_compare = ['dgm(CORUNDUM)', 'dgm(SPINEL)', 'dgm(HALITE)', 'dgm(LIQUID)' ]

for phase in phases_list:
    column_name = f'dgm({phase})'
    condition = df_DGM[column_name] == df_DGM[columns_to_compare].max(axis=1)
    globals()[f'df_DGM_{phase}'] = df_DGM[condition]


# Plotting the individual dataframes
plt.figure(figsize=(5, 5))

for i, phase in enumerate(phases_list):
    if phase == 'LIQUID' or phase == 'CORUNDUM':
        pass
    else:
        df = globals()[f'df_DGM_{phase}']
        plt.scatter(df['lnacr_o'], df['T']-273.15, s=10, label=labels_list[i],
                    color=colors[phase], alpha=1)
plt.scatter([-7.9663978], [300], color='white')
plt.xlabel('Natural log of oxygen activity', fontsize=14)
plt.ylabel(r'T ($^\circ$C)', fontsize=14)
plt.title('Maximum chemical driving force for nucleation', fontsize=14)
plt.legend(fontsize=12, loc='upper left',
           facecolor='white', edgecolor='black', framealpha=0.9)
plt.grid(True, which='both', linestyle='--', linewidth=0.4)
plt.xlim([min(df_DGM['lnacr_o']), max(df_DGM['lnacr_o'])])
plt.ylim([min(df_DGM['T'])-273.15, max(df_DGM['T'])-273.15])
plt.tight_layout()

plt_output_fname = "_DGMmax.png"
plt.savefig(os.path.join(current_directory, output_fname+plt_output_fname),
            format='png', dpi=300,  bbox_inches='tight')
plt.show()
